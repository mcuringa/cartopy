# %% [markdown]
# Lab 3: Plotting points
# ======================
# **Goals:**
#
# - using `geopandas` and reading spatial data files
# - write functions with parameters and `return` values
# - use the apply() function to apply a function to a column
# - create interactive maps with GeoPandas
#
#
# **Topics:**
#
# - format percentages as strings
# - plot points on a map
# - change the base map
# - customize the title and popup
# - use colors to represent data
# - use radius size to represent data

# %%
# import pandas library
import pandas as pd
import geopandas as gpd


# read the data from a URL
# this data combines US cenus data from the ACS with
# UC census tigerline data for place points and land area
url = "https://raw.githubusercontent.com/mcuringa/cartopy/main/notebooks/data/city-points.geojson"


# read the data into a pandas DataFrame
df = gpd.read_file(url)

# display the GeoDataFrame, note the special geometry column
df
# Out:
#                city state  pop_2022  pop_2017        area  \
# 0          New York    NY   8622467   8560072  300.455595
# 1       Los Angeles    CA   3881041   3949776  470.514345
# 2           Chicago    IL   2721914   2722586  227.746682
# 3           Houston    TX   2296253   2267336  640.602800
# 4           Phoenix    AZ   1609456   1574421  518.327625
# ..              ...   ...       ...       ...         ...
# 334  San Tan Valley    AZ    101207     90665   75.792311
# 335          Quincy    MA    100981     93824   16.572565
# 336        Edinburg    TX    100964     86123   44.722438
# 337            Lynn    MA    100653     93069   10.738836
# 338     New Bedford    MA    100620     95125   20.000777
#
#                         geometry
# 0     POINT (-73.93868 40.66271)
# 1    POINT (-118.41082 34.01939)
# 2     POINT (-87.68494 41.83705)
# 3     POINT (-95.38881 29.78574)
# 4    POINT (-112.09013 33.57215)
# ..                           ...
# 334  POINT (-111.56282 33.17859)
# 335   POINT (-71.00899 42.26101)
# 336   POINT (-98.16284 26.32106)
# 337   POINT (-70.96203 42.47477)
# 338    POINT (-70.93791 41.6613)
#
# [339 rows x 6 columns]

# %%
# use plot() to make a static map

df.plot()
# Out:
# <Axes: >

# %%
# use explore() to make an interactive map
df.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cd5cf46bf8ee633a48f7bf30b7d0148 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cd5cf46bf8ee633a48f7bf30b7d0148&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8cd5cf46bf8ee633a48f7bf30b7d0148 = L.map(
#                 &quot;map_8cd5cf46bf8ee633a48f7bf30b7d0148&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_8cd5cf46bf8ee633a48f7bf30b7d0148);
#
#
#
#
#
#             var tile_layer_81c2576edb256f1b8554e40ad040f246 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_81c2576edb256f1b8554e40ad040f246.addTo(map_8cd5cf46bf8ee633a48f7bf30b7d0148);
#
#
#             map_8cd5cf46bf8ee633a48f7bf30b7d0148.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_53340c0e91f4ae859e267161d8f7911f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_53340c0e91f4ae859e267161d8f7911f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_53340c0e91f4ae859e267161d8f7911f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_53340c0e91f4ae859e267161d8f7911f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_53340c0e91f4ae859e267161d8f7911f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_53340c0e91f4ae859e267161d8f7911f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_53340c0e91f4ae859e267161d8f7911f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_53340c0e91f4ae859e267161d8f7911f = L.geoJson(null, {
#                 onEachFeature: geo_json_53340c0e91f4ae859e267161d8f7911f_onEachFeature,
#
#                 style: geo_json_53340c0e91f4ae859e267161d8f7911f_styler,
#                 pointToLayer: geo_json_53340c0e91f4ae859e267161d8f7911f_pointToLayer,
#         });
#
#         function geo_json_53340c0e91f4ae859e267161d8f7911f_add (data) {
#             geo_json_53340c0e91f4ae859e267161d8f7911f
#                 .addData(data);
#         }
#             geo_json_53340c0e91f4ae859e267161d8f7911f_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;area&quot;: 300.4555945248, &quot;city&quot;: &quot;New York&quot;, &quot;pop_2017&quot;: 8560072, &quot;pop_2022&quot;: 8622467, &quot;state&quot;: &quot;NY&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-118.4108248, 34.0193936, -118.4108248, 34.0193936], &quot;geometry&quot;: {&quot;coordinates&quot;: [-118.4108248, 34.0193936], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;prope

# %%
# calculate the 5 year change in population
# calculate the 5 year change in percent of population
# write a function to format a real number as a percentage


# first, some very simple functions

def times2(n):
    print("running times2")
    print(f"the number is {n}")
    return n * 2


# print("calling times2(4)", times2(4))
# print("calling times2(8)", times2(8))
# print("calling times2(16)", times2(16))

def power(base, exp):
    return base**exp

# power(10, -1)

# now that string formatting function

# use apply() to map the function to a column

def fmt_number(n):
    return f"{n:,.2f}"

df["density"] = df.pop_2022 / df["area"]
df[["city", "pop_2022", "density"]]

table = df.sort_values(by="density", ascending=False).head(20).copy()
table["density_pp"] = table.density.apply(fmt_number)
table[["city", "density"]]

table.density_pp
table
# Out:
#                  city state  pop_2022  pop_2017        area  \
# 0            New York    NY   8622467   8560072  300.455595
# 73        Jersey City    NJ    287899    265932   14.747956
# 169          Paterson    NJ    157864    147890    8.413162
# 253         Cambridge    MA    117962    110893    6.396859
# 16      San Francisco    CA    851036    864263   46.699439
# 255  East Los Angeles    CA    117222    123905    7.453105
# 23             Boston    MA    665945    669158   48.339976
# 323         Daly City    CA    103648    106480    7.638415
# 66             Newark    NJ    307355    282803   24.143368
# 43              Miami    FL    443665    443007   35.995486
# 2             Chicago    IL   2721914   2722586  227.746682
# 5        Philadelphia    PA   1593208   1569657  134.355706
# 304         Inglewood    CA    106806    111006    9.067247
# 112           Yonkers    NY    209780    200999   18.005557
# 243          Berkeley    CA    121385    120179   10.431769
# 62          Santa Ana    CA    311379    334493   27.376249
# 296          El Monte    CA    108682    115958    9.557096
# 214         Elizabeth    NJ    135665    129363   12.318702
# 22         Washington  None    670587    672391   61.125879
# 170        Alexandria    VA    157594    154710   14.935248
#
#                         geometry       density density_pp
# 0     POINT (-73.93868 40.66271)  28697.974533  28,697.97
# 73    POINT (-74.06476 40.71142)  19521.282090  19,521.28
# 169   POINT (-74.16283 40.91477)  18763.932358  18,763.93
# 253   POINT (-71.11868 42.37604)  18440.613228  18,440.61
# 16   POINT (-123.03223 37.72724)  18223.687713  18,223.69
# 255  POINT (-118.16857 34.03151)  15727.942597  15,727.94
# 23    POINT (-71.01825 42.33855)  13776.278972  13,776.28
# 323  POINT (-122.46867 37.68619)  13569.306994  13,569.31
# 66    POINT (-74.17257 40.72422)  12730.411030  12,730.41
# 43    POINT (-80.20862 25.77516)  12325.573264  12,325.57
# 2     POINT (-87.68494 41.83705)  11951.497962  11,951.50
# 5     POINT (-75.13335 40.00938)  11858.134241  11,858.13
# 304  POINT (-118.34427 33.95607)  11779.319674  11,779.32
# 112   POINT (-73.86745 40.94586)  11650.847385  11,650.85
# 243  POINT (-122.29872 37.86567)  11636.089601  11,636.09
# 62    POINT (-117.8829 33.73633)  11374.056525  11,374.06
# 296  POINT (-118.02914 34.07463)  11371.864145  11,371.86
# 214    POINT (-74.1935 40.66637)  11012.929456  11,012.93
# 22    POINT (-77.01652 38.90425)  10970.590769  10,970.59
# 170   POINT (-77.08367 38.81925)  10551.816477  10,551.82

# %%
# create a new column for the mouseover tooltip label
# use apply() for the whole row with axis=1

# turn of the extra label with tooltip_kwds={"labels": False}

def make_tooltip(row):
    return f"{row.city} (pop. {row.pop_2022:,})"

df["tooltip"] = df.apply(make_tooltip, axis=1)

df.explore(tooltip=None, popup=["city", "state"], popup_kwds={"labels": False})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13151a9d4e0b0968b2ed914a00c1d259 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13151a9d4e0b0968b2ed914a00c1d259&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13151a9d4e0b0968b2ed914a00c1d259 = L.map(
#                 &quot;map_13151a9d4e0b0968b2ed914a00c1d259&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_13151a9d4e0b0968b2ed914a00c1d259);
#
#
#
#
#
#             var tile_layer_af6299e9bf6d85ba0d71793ee08bc6d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_af6299e9bf6d85ba0d71793ee08bc6d6.addTo(map_13151a9d4e0b0968b2ed914a00c1d259);
#
#
#             map_13151a9d4e0b0968b2ed914a00c1d259.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_a3f88088e772dece045666e1d1dd33e4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a3f88088e772dece045666e1d1dd33e4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a3f88088e772dece045666e1d1dd33e4_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a3f88088e772dece045666e1d1dd33e4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a3f88088e772dece045666e1d1dd33e4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_a3f88088e772dece045666e1d1dd33e4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a3f88088e772dece045666e1d1dd33e4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a3f88088e772dece045666e1d1dd33e4 = L.geoJson(null, {
#                 onEachFeature: geo_json_a3f88088e772dece045666e1d1dd33e4_onEachFeature,
#
#                 style: geo_json_a3f88088e772dece045666e1d1dd33e4_styler,
#                 pointToLayer: geo_json_a3f88088e772dece045666e1d1dd33e4_pointToLayer,
#         });
#
#         function geo_json_a3f88088e772dece045666e1d1dd33e4_add (data) {
#             geo_json_a3f88088e772dece045666e1d1dd33e4
#                 .addData(data);
#         }
#             geo_json_a3f88088e772dece045666e1d1dd33e4_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;area&quot;: 300.4555945248, &quot;city&quot;: &quot;New York&quot;, &quot;density&quot;: 28697.974533099565, &quot;pop_2017&quot;: 8560072, &quot;pop_2022&quot;: 8622467, &quot;state&quot;: &quot;NY&quot;, &quot;tooltip&quot;: &quot;New York (pop. 8,622,467)&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-118.4108248, 34.0193936, -118.4108248, 34.0193936], &quot;geometry&quot;: {&quot;coordinates&quot;: [-

# %%
# onclick popups

df.explore(tooltip="tooltip", tooltip_kwds={"labels": False}, popup=["city", "state"])
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87dda291142b156637e4502d9f6ed522 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87dda291142b156637e4502d9f6ed522&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87dda291142b156637e4502d9f6ed522 = L.map(
#                 &quot;map_87dda291142b156637e4502d9f6ed522&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_87dda291142b156637e4502d9f6ed522);
#
#
#
#
#
#             var tile_layer_1092ba52069efa64062bc4eb660f3272 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1092ba52069efa64062bc4eb660f3272.addTo(map_87dda291142b156637e4502d9f6ed522);
#
#
#             map_87dda291142b156637e4502d9f6ed522.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_0c902c040e983670fa54919db814328e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0c902c040e983670fa54919db814328e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0c902c040e983670fa54919db814328e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0c902c040e983670fa54919db814328e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0c902c040e983670fa54919db814328e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_0c902c040e983670fa54919db814328e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0c902c040e983670fa54919db814328e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0c902c040e983670fa54919db814328e = L.geoJson(null, {
#                 onEachFeature: geo_json_0c902c040e983670fa54919db814328e_onEachFeature,
#
#                 style: geo_json_0c902c040e983670fa54919db814328e_styler,
#                 pointToLayer: geo_json_0c902c040e983670fa54919db814328e_pointToLayer,
#         });
#
#         function geo_json_0c902c040e983670fa54919db814328e_add (data) {
#             geo_json_0c902c040e983670fa54919db814328e
#                 .addData(data);
#         }
#             geo_json_0c902c040e983670fa54919db814328e_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 4

# %%
# get the packages we need to change the tiles/base map
# xyz has the data on the providers, we use it to build the URL and attribution
import xyzservices.providers as xyz

# change the basemap to use the CartoDB DarkMatterNoLabels tiles

# df.explore(tiles=xyz.CartoDB.DarkMatterNoLabels, attr=xyz.CartoDB.DarkMatterNoLabels)

# divide the cities into small, medium, and large
small = df[df.pop_2022 < 500_000]
medium = df[(df.pop_2022 >= 500_000) & (df.pop_2022 <=1_000_000)]
large = df[df.pop_2022 > 1_000_000]


# plot them on the same map, with different colors and radius size
# note: you can use any hex color or HTML named color
# see: https://developer.mozilla.org/en-US/docs/Web/CSS/named-color

m = small.explore(tiles=xyz.CartoDB.DarkMatterNoLabels,
                  attr=xyz.CartoDB.DarkMatterNoLabels,
                  color="blue", style_kwds={"radius": 5}, tooltip="tooltip", tooltip_kwds={"labels": False})
m = medium.explore(m=m, color="green", style_kwds={"radius": 7}, tooltip="tooltip", tooltip_kwds={"labels": False})
m = large.explore(m=m,color="red", style_kwds={"radius": 10}, tooltip="tooltip", tooltip_kwds={"labels": False})

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b92dc0a9d87737a0c0542863a2b0a5f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b92dc0a9d87737a0c0542863a2b0a5f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b92dc0a9d87737a0c0542863a2b0a5f4 = L.map(
#                 &quot;map_b92dc0a9d87737a0c0542863a2b0a5f4&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b92dc0a9d87737a0c0542863a2b0a5f4);
#
#
#
#
#
#             var tile_layer_a0d79669455519f4d78a4fde2c339777 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/dark_nolabels/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;CartoDB.DarkMatterNoLabels&quot;, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;url&quot;: &quot;https://{s}.basemaps.cartocdn.com/{variant}/{z}/{x}/{y}{r}.png&quot;, &quot;variant&quot;: &quot;dark_nolabels&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a0d79669455519f4d78a4fde2c339777.addTo(map_b92dc0a9d87737a0c0542863a2b0a5f4);
#
#
#             map_b92dc0a9d87737a0c0542863a2b0a5f4.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_46f7ad282b6722bbc88031608e284a28_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_46f7ad282b6722bbc88031608e284a28_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_46f7ad282b6722bbc88031608e284a28_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_46f7ad282b6722bbc88031608e284a28_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_46f7ad282b6722bbc88031608e284a28_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_46f7ad282b6722bbc88031608e284a28.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.

# %% [markdown]
# <hr>
#
# Tile Providers
# ==============
# There are many different basemap tile providers
# that can work with `geopandas` and `folium`.
# Below we present our data with a few of them.
# OpenStreetMap is the default tile provider.
# CartoDB provides a good set of tiles, that have
# "labels" and "no label" options.
#
# [**You can find a gallery of tile providers here.**](https://xyzservices.readthedocs.io/en/stable/gallery.html)

# %%
# list all of the base map options for explore()
# import these to make nicer descriptions for the maps
from IPython.display import display, HTML

# xyz has the data on the providers, we use it to build the URL and attribution
import xyzservices.providers as xyz

# these are a few of the selected tiles
tiles = [xyz.OpenStreetMap.Mapnik, xyz.CartoDB.Positron, xyz.CartoDB.PositronNoLabels,
         xyz.CartoDB.DarkMatter, xyz.CartoDB.DarkMatterNoLabels,
         xyz.CartoDB.Voyager, xyz.USGS.USImageryTopo,
         xyz.USGS.USImagery, xyz.USGS.USTopo, xyz.OpenTopoMap]


for provider in tiles:
    display(HTML(f"<h2>{provider.name}</h2>"))
    display(HTML(
        f"""<tt>df.explore(tiles=xyz.{provider.name}.url, attr=xyz.{provider.name}.attribution)</tt>"""))
    display(HTML(provider.html_attribution))
    display(df.explore(tiles=provider, attr=provider))
# Out:
# <h2>OpenStreetMap.Mapnik</h2>
# <tt>df.explore(tiles=xyz.OpenStreetMap.Mapnik.url, attr=xyz.OpenStreetMap.Mapnik.attribution)</tt>
# &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7f0ffcd7d1a9c4b685498c98e46e718 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7f0ffcd7d1a9c4b685498c98e46e718&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7f0ffcd7d1a9c4b685498c98e46e718 = L.map(
#                 &quot;map_b7f0ffcd7d1a9c4b685498c98e46e718&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b7f0ffcd7d1a9c4b685498c98e46e718);
#
#
#
#
#
#             var tile_layer_770f432aa0a582e4c087a6d4e76b8911 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;max_zoom&quot;: 19, &quot;name&quot;: &quot;OpenStreetMap.Mapnik&quot;, &quot;url&quot;: &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_770f432aa0a582e4c087a6d4e76b8911.addTo(map_b7f0ffcd7d1a9c4b685498c98e46e718);
#
#
#             map_b7f0ffcd7d1a9c4b685498c98e46e718.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c = L.geoJson(null, {
#                 onEachFeature: geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_onEachFeature,
#
#                 style: geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_styler,
#                 pointToLayer: geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_pointToLayer,
#         });
#
#         function geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_add (data) {
#             geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c
#                 .addData(data);
#         }
#             geo_json_a29d3cc9ac695cca7a5adc6ecde9e73c_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;area&quot;: 300.4555945248, &quot;city&quot;: &quot;New York&quot;, &quot;density&quot;: 28697.974533099565, &quot;pop_2017&quot;: 8560072, &quot;pop_2022&quot;: 8622467, &quot;state&quot;: &quot;NY&quot;, &quo
# <h2>CartoDB.Positron</h2>
# <tt>df.explore(tiles=xyz.CartoDB.Positron.url, attr=xyz.CartoDB.Positron.attribution)</tt>
# &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da4bf80fc8d57777f5f6fc317c78236a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da4bf80fc8d57777f5f6fc317c78236a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da4bf80fc8d57777f5f6fc317c78236a = L.map(
#                 &quot;map_da4bf80fc8d57777f5f6fc317c78236a&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_da4bf80fc8d57777f5f6fc317c78236a);
#
#
#
#
#
#             var tile_layer_7bf8db97b3f51a253e96eb9fbe152049 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;CartoDB.Positron&quot;, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;url&quot;: &quot;https://{s}.basemaps.cartocdn.com/{variant}/{z}/{x}/{y}{r}.png&quot;, &quot;variant&quot;: &quot;light_all&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7bf8db97b3f51a253e96eb9fbe152049.addTo(map_da4bf80fc8d57777f5f6fc317c78236a);
#
#
#             map_da4bf80fc8d57777f5f6fc317c78236a.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_5e87cb1d896c0f119d6430a0c695259f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5e87cb1d896c0f119d6430a0c695259f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5e87cb1d896c0f119d6430a0c695259f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5e87cb1d896c0f119d6430a0c695259f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5e87cb1d896c0f119d6430a0c695259f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5e87cb1d896c0f119d6430a0c695259f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5e87cb1d896c0f119d6430a0c695259f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5e87cb1d896c0f119d6430a0c695259f = L.geoJson(null, {
#                 onEachFeature: geo_json_5e87cb1d896c0f119d6430a0c695259f_onEachFeature,
#
#                 style: geo_json_5e87cb1d896c0f119d6430a0c695259f_styler,
#                 pointToLayer: geo_json_5e87cb1d896c0f119d6430a0c695259f_pointToLayer,
#         });
#
#         function geo_json_5e87cb1d896c0f119d6430a0c695259f_add (data) {
#             geo_json_5e87cb1d896c0f119d6430a0c695259f
#                 .addData(data);
#         }
#             geo_json_5e87cb1d896c0f119d6430a0c695259f_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;:
# <h2>CartoDB.PositronNoLabels</h2>
# <tt>df.explore(tiles=xyz.CartoDB.PositronNoLabels.url, attr=xyz.CartoDB.PositronNoLabels.attribution)</tt>
# &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_656878414b0e871932daef3959ca4955 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_656878414b0e871932daef3959ca4955&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_656878414b0e871932daef3959ca4955 = L.map(
#                 &quot;map_656878414b0e871932daef3959ca4955&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_656878414b0e871932daef3959ca4955);
#
#
#
#
#
#             var tile_layer_1ec165399f887aba9a7ca91ec700974e = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_nolabels/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;CartoDB.PositronNoLabels&quot;, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;url&quot;: &quot;https://{s}.basemaps.cartocdn.com/{variant}/{z}/{x}/{y}{r}.png&quot;, &quot;variant&quot;: &quot;light_nolabels&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_1ec165399f887aba9a7ca91ec700974e.addTo(map_656878414b0e871932daef3959ca4955);
#
#
#             map_656878414b0e871932daef3959ca4955.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_1abc903bd01594d07683742b90a3184f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1abc903bd01594d07683742b90a3184f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1abc903bd01594d07683742b90a3184f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_1abc903bd01594d07683742b90a3184f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1abc903bd01594d07683742b90a3184f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1abc903bd01594d07683742b90a3184f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1abc903bd01594d07683742b90a3184f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_1abc903bd01594d07683742b90a3184f = L.geoJson(null, {
#                 onEachFeature: geo_json_1abc903bd01594d07683742b90a3184f_onEachFeature,
#
#                 style: geo_json_1abc903bd01594d07683742b90a3184f_styler,
#                 pointToLayer: geo_json_1abc903bd01594d07683742b90a3184f_pointToLayer,
#         });
#
#         function geo_json_1abc903bd01594d07683742b90a3184f_add (data) {
#             geo_json_1abc903bd01594d07683742b90a3184f
#                 .addData(data);
#         }
#             geo_json_1abc903bd01594d07683742b90a3184f_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;
# <h2>CartoDB.DarkMatter</h2>
# <tt>df.explore(tiles=xyz.CartoDB.DarkMatter.url, attr=xyz.CartoDB.DarkMatter.attribution)</tt>
# &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7d4608f7913b71a56c76b679f46f8b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7d4608f7913b71a56c76b679f46f8b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7d4608f7913b71a56c76b679f46f8b4 = L.map(
#                 &quot;map_b7d4608f7913b71a56c76b679f46f8b4&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b7d4608f7913b71a56c76b679f46f8b4);
#
#
#
#
#
#             var tile_layer_d84c171c590f4df3b0751cffa21a06ac = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;CartoDB.DarkMatter&quot;, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;url&quot;: &quot;https://{s}.basemaps.cartocdn.com/{variant}/{z}/{x}/{y}{r}.png&quot;, &quot;variant&quot;: &quot;dark_all&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_d84c171c590f4df3b0751cffa21a06ac.addTo(map_b7d4608f7913b71a56c76b679f46f8b4);
#
#
#             map_b7d4608f7913b71a56c76b679f46f8b4.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_ba3b44154ef349cc4dbcce000f5664ad_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ba3b44154ef349cc4dbcce000f5664ad_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ba3b44154ef349cc4dbcce000f5664ad_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_ba3b44154ef349cc4dbcce000f5664ad_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ba3b44154ef349cc4dbcce000f5664ad_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ba3b44154ef349cc4dbcce000f5664ad.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ba3b44154ef349cc4dbcce000f5664ad_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ba3b44154ef349cc4dbcce000f5664ad = L.geoJson(null, {
#                 onEachFeature: geo_json_ba3b44154ef349cc4dbcce000f5664ad_onEachFeature,
#
#                 style: geo_json_ba3b44154ef349cc4dbcce000f5664ad_styler,
#                 pointToLayer: geo_json_ba3b44154ef349cc4dbcce000f5664ad_pointToLayer,
#         });
#
#         function geo_json_ba3b44154ef349cc4dbcce000f5664ad_add (data) {
#             geo_json_ba3b44154ef349cc4dbcce000f5664ad
#                 .addData(data);
#         }
#             geo_json_ba3b44154ef349cc4dbcce000f5664ad_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;:
# <h2>CartoDB.DarkMatterNoLabels</h2>
# <tt>df.explore(tiles=xyz.CartoDB.DarkMatterNoLabels.url, attr=xyz.CartoDB.DarkMatterNoLabels.attribution)</tt>
# &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_439761747cd4a624257e31b3493c737d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_439761747cd4a624257e31b3493c737d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_439761747cd4a624257e31b3493c737d = L.map(
#                 &quot;map_439761747cd4a624257e31b3493c737d&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_439761747cd4a624257e31b3493c737d);
#
#
#
#
#
#             var tile_layer_9d208e28026a7b0aaa9aa751a581fa61 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/dark_nolabels/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;CartoDB.DarkMatterNoLabels&quot;, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;url&quot;: &quot;https://{s}.basemaps.cartocdn.com/{variant}/{z}/{x}/{y}{r}.png&quot;, &quot;variant&quot;: &quot;dark_nolabels&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9d208e28026a7b0aaa9aa751a581fa61.addTo(map_439761747cd4a624257e31b3493c737d);
#
#
#             map_439761747cd4a624257e31b3493c737d.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_7179191fd3a7aa6d8dac7e4357634e45_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_7179191fd3a7aa6d8dac7e4357634e45_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_7179191fd3a7aa6d8dac7e4357634e45_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_7179191fd3a7aa6d8dac7e4357634e45_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_7179191fd3a7aa6d8dac7e4357634e45_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_7179191fd3a7aa6d8dac7e4357634e45.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_7179191fd3a7aa6d8dac7e4357634e45_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_7179191fd3a7aa6d8dac7e4357634e45 = L.geoJson(null, {
#                 onEachFeature: geo_json_7179191fd3a7aa6d8dac7e4357634e45_onEachFeature,
#
#                 style: geo_json_7179191fd3a7aa6d8dac7e4357634e45_styler,
#                 pointToLayer: geo_json_7179191fd3a7aa6d8dac7e4357634e45_pointToLayer,
#         });
#
#         function geo_json_7179191fd3a7aa6d8dac7e4357634e45_add (data) {
#             geo_json_7179191fd3a7aa6d8dac7e4357634e45
#                 .addData(data);
#         }
#             geo_json_7179191fd3a7aa6d8dac7e4357634e45_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;
# <h2>CartoDB.Voyager</h2>
# <tt>df.explore(tiles=xyz.CartoDB.Voyager.url, attr=xyz.CartoDB.Voyager.attribution)</tt>
# &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_118e65d717a13389e3cb5ee19b96fbae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_118e65d717a13389e3cb5ee19b96fbae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_118e65d717a13389e3cb5ee19b96fbae = L.map(
#                 &quot;map_118e65d717a13389e3cb5ee19b96fbae&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_118e65d717a13389e3cb5ee19b96fbae);
#
#
#
#
#
#             var tile_layer_949bfccaa5e8bf2c64117e1602fa5b14 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/rastertiles/voyager/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;CartoDB.Voyager&quot;, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;url&quot;: &quot;https://{s}.basemaps.cartocdn.com/{variant}/{z}/{x}/{y}{r}.png&quot;, &quot;variant&quot;: &quot;rastertiles/voyager&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_949bfccaa5e8bf2c64117e1602fa5b14.addTo(map_118e65d717a13389e3cb5ee19b96fbae);
#
#
#             map_118e65d717a13389e3cb5ee19b96fbae.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_18975d6be9113d604fe80d8247039c12_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_18975d6be9113d604fe80d8247039c12_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_18975d6be9113d604fe80d8247039c12_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_18975d6be9113d604fe80d8247039c12_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
# ...
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2defe8b7687b9c5822ee01092293bdb7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2defe8b7687b9c5822ee01092293bdb7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2defe8b7687b9c5822ee01092293bdb7 = L.map(
#                 &quot;map_2defe8b7687b9c5822ee01092293bdb7&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2defe8b7687b9c5822ee01092293bdb7);
#
#
#
#
#
#             var tile_layer_0720c25491cb8249ed814885f73634a2 = L.tileLayer(
#                 &quot;https://basemap.nationalmap.gov/arcgis/rest/services/USGSTopo/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;Tiles courtesy of the U.S. Geological Survey&quot;, &quot;html_attribution&quot;: &quot;Tiles courtesy of the \u003ca href=\&quot;https://usgs.gov/\&quot;\u003eU.S. Geological Survey\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;USGS.USTopo&quot;, &quot;url&quot;: &quot;https://basemap.nationalmap.gov/arcgis/rest/services/USGSTopo/MapServer/tile/{z}/{y}/{x}&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0720c25491cb8249ed814885f73634a2.addTo(map_2defe8b7687b9c5822ee01092293bdb7);
#
#
#             map_2defe8b7687b9c5822ee01092293bdb7.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_5f30b84d95d3b739a0f915b175c34165_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5f30b84d95d3b739a0f915b175c34165_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5f30b84d95d3b739a0f915b175c34165_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5f30b84d95d3b739a0f915b175c34165_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5f30b84d95d3b739a0f915b175c34165_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5f30b84d95d3b739a0f915b175c34165.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5f30b84d95d3b739a0f915b175c34165_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5f30b84d95d3b739a0f915b175c34165 = L.geoJson(null, {
#                 onEachFeature: geo_json_5f30b84d95d3b739a0f915b175c34165_onEachFeature,
#
#                 style: geo_json_5f30b84d95d3b739a0f915b175c34165_styler,
#                 pointToLayer: geo_json_5f30b84d95d3b739a0f915b175c34165_pointToLayer,
#         });
#
#         function geo_json_5f30b84d95d3b739a0f915b175c34165_add (data) {
#             geo_json_5f30b84d95d3b739a0f915b175c34165
#                 .addData(data);
#         }
#             geo_json_5f30b84d95d3b739a0f915b175c34165_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;area&quot;: 300.4555945248, &quot;city&quot;: &quot;New York&quot;, &quot;density&quot;: 28697.974533099565, &quot;pop_2017&quot;: 856007
# <h2>OpenTopoMap</h2>
# <tt>df.explore(tiles=xyz.OpenTopoMap.url, attr=xyz.OpenTopoMap.attribution)</tt>
# Map data: &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, <a href="http://viewfinderpanoramas.org">SRTM</a> | Map style: &copy; <a href="https://opentopomap.org">OpenTopoMap</a> (<a href="https://creativecommons.org/licenses/by-sa/3.0/">CC-BY-SA</a>)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e639fb9c2d0b48a14002152ac70d1cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e639fb9c2d0b48a14002152ac70d1cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e639fb9c2d0b48a14002152ac70d1cf = L.map(
#                 &quot;map_7e639fb9c2d0b48a14002152ac70d1cf&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_7e639fb9c2d0b48a14002152ac70d1cf);
#
#
#
#
#
#             var tile_layer_5027cd0bd878d1bb5024901f0db6fb7e = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;Map data: (C) OpenStreetMap contributors, SRTM | Map style: (C) OpenTopoMap (CC-BY-SA)&quot;, &quot;html_attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u003ca href=\&quot;http://viewfinderpanoramas.org\&quot;\u003eSRTM\u003c/a\u003e | Map style: \u0026copy; \u003ca href=\&quot;https://opentopomap.org\&quot;\u003eOpenTopoMap\u003c/a\u003e (\u003ca href=\&quot;https://creativecommons.org/licenses/by-sa/3.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e)&quot;, &quot;max_zoom&quot;: 17, &quot;name&quot;: &quot;OpenTopoMap&quot;, &quot;url&quot;: &quot;https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 17, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_5027cd0bd878d1bb5024901f0db6fb7e.addTo(map_7e639fb9c2d0b48a14002152ac70d1cf);
#
#
#             map_7e639fb9c2d0b48a14002152ac70d1cf.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5 = L.geoJson(null, {
#                 onEachFeature: geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_onEachFeature,
#
#                 style: geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_styler,
#                 pointToLayer: geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_pointToLayer,
#         });
#
#         function geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_add (data) {
#             geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5
#                 .addData(data);
#         }
#             geo_json_ecb5fe8283e4e9d2e047d4b81e665ff5_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;co

# %%
show_tile(tiles[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[199], line 1
# ----> 1 show_tile(tiles[1])
#
# NameError: name 'show_tile' is not defined

# %%
show_tile(tiles[2])
# Out:
# <h2>CartoDB.DarkMatter</h2>
# <tt>df.explore(tiles=xyz.CartoDB.DarkMatter.url, attr=xyz.CartoDB.DarkMatter.attribution)</tt>
# &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_406754e82c810907f454db896e31f340 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_406754e82c810907f454db896e31f340&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_406754e82c810907f454db896e31f340 = L.map(
#                 &quot;map_406754e82c810907f454db896e31f340&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_406754e82c810907f454db896e31f340);
#
#
#
#
#
#             var tile_layer_72e15f14bed6c5e7c38cadd70742decb = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/dark_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;CartoDB.DarkMatter&quot;, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;url&quot;: &quot;https://{s}.basemaps.cartocdn.com/{variant}/{z}/{x}/{y}{r}.png&quot;, &quot;variant&quot;: &quot;dark_all&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_72e15f14bed6c5e7c38cadd70742decb.addTo(map_406754e82c810907f454db896e31f340);
#
#
#             map_406754e82c810907f454db896e31f340.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_9197f7eb0684ddb5fe777ec119daf2dc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_9197f7eb0684ddb5fe777ec119daf2dc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_9197f7eb0684ddb5fe777ec119daf2dc_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_9197f7eb0684ddb5fe777ec119daf2dc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_9197f7eb0684ddb5fe777ec119daf2dc_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_9197f7eb0684ddb5fe777ec119daf2dc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_9197f7eb0684ddb5fe777ec119daf2dc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_9197f7eb0684ddb5fe777ec119daf2dc = L.geoJson(null, {
#                 onEachFeature: geo_json_9197f7eb0684ddb5fe777ec119daf2dc_onEachFeature,
#
#                 style: geo_json_9197f7eb0684ddb5fe777ec119daf2dc_styler,
#                 pointToLayer: geo_json_9197f7eb0684ddb5fe777ec119daf2dc_pointToLayer,
#         });
#
#         function geo_json_9197f7eb0684ddb5fe777ec119daf2dc_add (data) {
#             geo_json_9197f7eb0684ddb5fe777ec119daf2dc
#                 .addData(data);
#         }
#             geo_json_9197f7eb0684ddb5fe777ec119daf2dc_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;:

# %%
show_tile(tiles[3])
# Out:
# <h2>CartoDB.DarkMatterNoLabels</h2>
# <tt>df.explore(tiles=xyz.CartoDB.DarkMatterNoLabels.url, attr=xyz.CartoDB.DarkMatterNoLabels.attribution)</tt>
# &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors &copy; <a href="https://carto.com/attributions">CARTO</a>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f00c3f715468b70a56a1570f9d54a36e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f00c3f715468b70a56a1570f9d54a36e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f00c3f715468b70a56a1570f9d54a36e = L.map(
#                 &quot;map_f00c3f715468b70a56a1570f9d54a36e&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f00c3f715468b70a56a1570f9d54a36e);
#
#
#
#
#
#             var tile_layer_e9a2f9b47b8d21fcd18e09c003f91b06 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/dark_nolabels/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;html_attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;CartoDB.DarkMatterNoLabels&quot;, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;url&quot;: &quot;https://{s}.basemaps.cartocdn.com/{variant}/{z}/{x}/{y}{r}.png&quot;, &quot;variant&quot;: &quot;dark_nolabels&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e9a2f9b47b8d21fcd18e09c003f91b06.addTo(map_f00c3f715468b70a56a1570f9d54a36e);
#
#
#             map_f00c3f715468b70a56a1570f9d54a36e.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_f245eb6c3db355d0bdf612ad978f0dea_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_f245eb6c3db355d0bdf612ad978f0dea_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_f245eb6c3db355d0bdf612ad978f0dea_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_f245eb6c3db355d0bdf612ad978f0dea_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_f245eb6c3db355d0bdf612ad978f0dea_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_f245eb6c3db355d0bdf612ad978f0dea.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_f245eb6c3db355d0bdf612ad978f0dea_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_f245eb6c3db355d0bdf612ad978f0dea = L.geoJson(null, {
#                 onEachFeature: geo_json_f245eb6c3db355d0bdf612ad978f0dea_onEachFeature,
#
#                 style: geo_json_f245eb6c3db355d0bdf612ad978f0dea_styler,
#                 pointToLayer: geo_json_f245eb6c3db355d0bdf612ad978f0dea_pointToLayer,
#         });
#
#         function geo_json_f245eb6c3db355d0bdf612ad978f0dea_add (data) {
#             geo_json_f245eb6c3db355d0bdf612ad978f0dea
#                 .addData(data);
#         }
#             geo_json_f245eb6c3db355d0bdf612ad978f0dea_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;

# %%
show_tile(tiles[4])
# Out:
# <h2>USGS.USImageryTopo</h2>
# <tt>df.explore(tiles=xyz.USGS.USImageryTopo.url, attr=xyz.USGS.USImageryTopo.attribution)</tt>
# Tiles courtesy of the <a href="https://usgs.gov/">U.S. Geological Survey</a>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d4bac6f4111cb3d4dc3e410633f52c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d4bac6f4111cb3d4dc3e410633f52c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d4bac6f4111cb3d4dc3e410633f52c4 = L.map(
#                 &quot;map_0d4bac6f4111cb3d4dc3e410633f52c4&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0d4bac6f4111cb3d4dc3e410633f52c4);
#
#
#
#
#
#             var tile_layer_3e1584d79973ee72543691ca4e9e4954 = L.tileLayer(
#                 &quot;https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryTopo/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;Tiles courtesy of the U.S. Geological Survey&quot;, &quot;html_attribution&quot;: &quot;Tiles courtesy of the \u003ca href=\&quot;https://usgs.gov/\&quot;\u003eU.S. Geological Survey\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;USGS.USImageryTopo&quot;, &quot;url&quot;: &quot;https://basemap.nationalmap.gov/arcgis/rest/services/USGSImageryTopo/MapServer/tile/{z}/{y}/{x}&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3e1584d79973ee72543691ca4e9e4954.addTo(map_0d4bac6f4111cb3d4dc3e410633f52c4);
#
#
#             map_0d4bac6f4111cb3d4dc3e410633f52c4.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_70355df8e3312c960a3040da57b73905_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_70355df8e3312c960a3040da57b73905_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_70355df8e3312c960a3040da57b73905_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_70355df8e3312c960a3040da57b73905_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_70355df8e3312c960a3040da57b73905_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_70355df8e3312c960a3040da57b73905.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_70355df8e3312c960a3040da57b73905_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_70355df8e3312c960a3040da57b73905 = L.geoJson(null, {
#                 onEachFeature: geo_json_70355df8e3312c960a3040da57b73905_onEachFeature,
#
#                 style: geo_json_70355df8e3312c960a3040da57b73905_styler,
#                 pointToLayer: geo_json_70355df8e3312c960a3040da57b73905_pointToLayer,
#         });
#
#         function geo_json_70355df8e3312c960a3040da57b73905_add (data) {
#             geo_json_70355df8e3312c960a3040da57b73905
#                 .addData(data);
#         }
#             geo_json_70355df8e3312c960a3040da57b73905_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;area&quot;: 300.4555945248, &quot;city&quot;: &quot;New York&quot;, &quot;pop_2017&quot;: 8560072, &quot;pop_2022&qu

# %%
show_tile(tiles[5])
# Out:
# <h2>USGS.USTopo</h2>
# <tt>df.explore(tiles=xyz.USGS.USTopo.url, attr=xyz.USGS.USTopo.attribution)</tt>
# Tiles courtesy of the <a href="https://usgs.gov/">U.S. Geological Survey</a>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_838f4ab6339a040822776c6a6f37bd65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_838f4ab6339a040822776c6a6f37bd65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_838f4ab6339a040822776c6a6f37bd65 = L.map(
#                 &quot;map_838f4ab6339a040822776c6a6f37bd65&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_838f4ab6339a040822776c6a6f37bd65);
#
#
#
#
#
#             var tile_layer_2dea3c5d234097a87d068845304ea2f3 = L.tileLayer(
#                 &quot;https://basemap.nationalmap.gov/arcgis/rest/services/USGSTopo/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;Tiles courtesy of the U.S. Geological Survey&quot;, &quot;html_attribution&quot;: &quot;Tiles courtesy of the \u003ca href=\&quot;https://usgs.gov/\&quot;\u003eU.S. Geological Survey\u003c/a\u003e&quot;, &quot;max_zoom&quot;: 20, &quot;name&quot;: &quot;USGS.USTopo&quot;, &quot;url&quot;: &quot;https://basemap.nationalmap.gov/arcgis/rest/services/USGSTopo/MapServer/tile/{z}/{y}/{x}&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2dea3c5d234097a87d068845304ea2f3.addTo(map_838f4ab6339a040822776c6a6f37bd65);
#
#
#             map_838f4ab6339a040822776c6a6f37bd65.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_4e2b31f04aadc5a5a9acea42a5432037_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4e2b31f04aadc5a5a9acea42a5432037_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_4e2b31f04aadc5a5a9acea42a5432037_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_4e2b31f04aadc5a5a9acea42a5432037_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_4e2b31f04aadc5a5a9acea42a5432037_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_4e2b31f04aadc5a5a9acea42a5432037.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4e2b31f04aadc5a5a9acea42a5432037_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4e2b31f04aadc5a5a9acea42a5432037 = L.geoJson(null, {
#                 onEachFeature: geo_json_4e2b31f04aadc5a5a9acea42a5432037_onEachFeature,
#
#                 style: geo_json_4e2b31f04aadc5a5a9acea42a5432037_styler,
#                 pointToLayer: geo_json_4e2b31f04aadc5a5a9acea42a5432037_pointToLayer,
#         });
#
#         function geo_json_4e2b31f04aadc5a5a9acea42a5432037_add (data) {
#             geo_json_4e2b31f04aadc5a5a9acea42a5432037
#                 .addData(data);
#         }
#             geo_json_4e2b31f04aadc5a5a9acea42a5432037_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;coordinates&quot;: [-73.9386769, 40.6627117], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;area&quot;: 300.4555945248, &quot;city&quot;: &quot;New York&quot;, &quot;pop_2017&quot;: 8560072, &quot;pop_2022&quot;: 8622467, &quot;s

# %%
show_tile(tiles[6])
# Out:
# <h2>OpenTopoMap</h2>
# <tt>df.explore(tiles=xyz.OpenTopoMap.url, attr=xyz.OpenTopoMap.attribution)</tt>
# Map data: &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors, <a href="http://viewfinderpanoramas.org">SRTM</a> | Map style: &copy; <a href="https://opentopomap.org">OpenTopoMap</a> (<a href="https://creativecommons.org/licenses/by-sa/3.0/">CC-BY-SA</a>)
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_837e3a5642dfc9e2f86fa4069dec4a7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_837e3a5642dfc9e2f86fa4069dec4a7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_837e3a5642dfc9e2f86fa4069dec4a7f = L.map(
#                 &quot;map_837e3a5642dfc9e2f86fa4069dec4a7f&quot;,
#                 {
#                     center: [39.5869806, -111.91372584648096],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_837e3a5642dfc9e2f86fa4069dec4a7f);
#
#
#
#
#
#             var tile_layer_2f084a80e4f523fe5bb1805685790ddc = L.tileLayer(
#                 &quot;https://a.tile.opentopomap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: {&quot;attribution&quot;: &quot;Map data: (C) OpenStreetMap contributors, SRTM | Map style: (C) OpenTopoMap (CC-BY-SA)&quot;, &quot;html_attribution&quot;: &quot;Map data: \u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors, \u003ca href=\&quot;http://viewfinderpanoramas.org\&quot;\u003eSRTM\u003c/a\u003e | Map style: \u0026copy; \u003ca href=\&quot;https://opentopomap.org\&quot;\u003eOpenTopoMap\u003c/a\u003e (\u003ca href=\&quot;https://creativecommons.org/licenses/by-sa/3.0/\&quot;\u003eCC-BY-SA\u003c/a\u003e)&quot;, &quot;max_zoom&quot;: 17, &quot;name&quot;: &quot;OpenTopoMap&quot;, &quot;url&quot;: &quot;https://{s}.tile.opentopomap.org/{z}/{x}/{y}.png&quot;}, &quot;detectRetina&quot;: false, &quot;maxZoom&quot;: 17, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_2f084a80e4f523fe5bb1805685790ddc.addTo(map_837e3a5642dfc9e2f86fa4069dec4a7f);
#
#
#             map_837e3a5642dfc9e2f86fa4069dec4a7f.fitBounds(
#                 [[17.9997109, -157.84764549296193], [61.1742503, -65.9798062]],
#                 {}
#             );
#
#
#         function geo_json_8dc11873d77e36fbc6164ad3e4ed9209_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8dc11873d77e36fbc6164ad3e4ed9209_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8dc11873d77e36fbc6164ad3e4ed9209_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8dc11873d77e36fbc6164ad3e4ed9209_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8dc11873d77e36fbc6164ad3e4ed9209_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_8dc11873d77e36fbc6164ad3e4ed9209.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8dc11873d77e36fbc6164ad3e4ed9209_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8dc11873d77e36fbc6164ad3e4ed9209 = L.geoJson(null, {
#                 onEachFeature: geo_json_8dc11873d77e36fbc6164ad3e4ed9209_onEachFeature,
#
#                 style: geo_json_8dc11873d77e36fbc6164ad3e4ed9209_styler,
#                 pointToLayer: geo_json_8dc11873d77e36fbc6164ad3e4ed9209_pointToLayer,
#         });
#
#         function geo_json_8dc11873d77e36fbc6164ad3e4ed9209_add (data) {
#             geo_json_8dc11873d77e36fbc6164ad3e4ed9209
#                 .addData(data);
#         }
#             geo_json_8dc11873d77e36fbc6164ad3e4ed9209_add({&quot;bbox&quot;: [-157.84764549296193, 17.9997109, -65.9798062, 61.1742503], &quot;features&quot;: [{&quot;bbox&quot;: [-73.9386769, 40.6627117, -73.9386769, 40.6627117], &quot;geometry&quot;: {&quot;co
