# %% [markdown]
# Language Tracts
# ===================
# **FYS: Maps that Matter**
#
# This Notebook works with census geospatial data at the **tract** level.
# Tracts represent an area wtih a popluaton of a few thousand people. In
# dense areas, tracts can be a few city blocks. In less dense areas, a
# tract might cover an entire town or larger rural area.
#
# These examples work with the home language data from **Concept Table C16001**.
#
#
# - [Census Data Homework Example](https://colab.research.google.com/drive/1jjJfKdQd2HLp20xvmCS4m5reZsyGGnuT?usp=sharing)

# %%
# !pip install us https://github.com/mcuringa/cartopy/raw/refs/heads/main/dist/maptools-latest.tar.gz -q
# %load_ext autoreload
# %autoreload 2

from maptools import census_vars, tiger, ui
import pandas as pd
import geopandas as gpd
import us
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# load the data
data_url = f"https://api.census.gov/data/2022/acs/acs5?get=group(C16001)&ucgid=pseudo(0500000US36081$1400000)"
meta_url = "https://api.census.gov/data/2022/acs/acs5"


df = census_vars.get(data_url, meta_url)

display(df.columns)
df.head(5)
# Out:
# Index(['total', 'speak_only_english', 'spanish',
#        'spanish_speak_english_very_well',
#        'spanish_speak_english_less_than_very_well', 'french_haitian_or_cajun',
#        'french_haitian_or_cajun_speak_english_very_well',
#        'french_haitian_or_cajun_speak_english_less_than_very_well',
#        'german_or_other_west_germanic_languages',
#        'german_or_other_west_germanic_languages_speak_english_very_well',
#        'german_or_other_west_germanic_languages_speak_english_less_than_very_well',
#        'russian_polish_or_other_slavic_languages',
#        'russian_polish_or_other_slavic_languages_speak_english_very_well',
#        'russian_polish_or_other_slavic_languages_speak_english_less_than_very_well',
#        'other_indo_european_languages',
#        'other_indo_european_languages_speak_english_very_well',
#        'other_indo_european_languages_speak_english_less_than_very_well',
#        'korean', 'korean_speak_english_very_well',
#        'korean_speak_english_less_than_very_well',
#        'chinese_incl_mandarin_cantonese',
#        'chinese_incl_mandarin_cantonese_speak_english_very_well',
#        'chinese_incl_mandarin_cantonese_speak_english_less_than_very_well',
#        'vietnamese', 'vietnamese_speak_english_very_well',
#        'vietnamese_speak_english_less_than_very_well', 'tagalog_incl_filipino',
#        'tagalog_incl_filipino_speak_english_very_well',
#        'tagalog_incl_filipino_speak_english_less_than_very_well',
#        'other_asian_and_pacific_island_languages',
#        'other_asian_and_pacific_island_languages_speak_english_very_well',
#        'other_asian_and_pacific_island_languages_speak_english_less_than_very_well',
#        'arabic', 'arabic_speak_english_very_well',
#        'arabic_speak_english_less_than_very_well',
#        'other_and_unspecified_languages',
#        'other_and_unspecified_languages_speak_english_very_well',
#        'other_and_unspecified_languages_speak_english_less_than_very_well',
#        'statefp', 'countyfp', 'tractce', 'geometry'],
#       dtype='object')
#      total  speak_only_english  spanish  spanish_speak_english_very_well  \
# 599      0                   0        0                                0
# 161      0                   0        0                                0
# 427   3716                3506       24                               24
# 261   1081                 330      599                              344
# 263   1730                 513     1086                              754
#
#      spanish_speak_english_less_than_very_well  french_haitian_or_cajun  \
# 599                                          0                        0
# 161                                          0                        0
# 427                                          0                        0
# 261                                        255                        0
# 263                                        332                       55
#
#      french_haitian_or_cajun_speak_english_very_well  \
# 599                                                0
# 161                                                0
# 427                                                0
# 261                                                0
# 263                                               55
#
#      french_haitian_or_cajun_speak_english_less_than_very_well  \
# 599                                                  0
# 161                                                  0
# 427                                                  0
# 261                                                  0
# 263                                                  0
#
#      german_or_other_west_germanic_languages  \
# 599                                        0
# 161                                        0
# 427                                       51
# 261                                        0
# 263                                        0
#
#      german_or_other_west_germanic_languages_speak_english_very_well  ...  \
# 599                                                  0                ...
# 161                                                  0                ...
# 427                                                 51                ...
# 261                                                  0                ...
# 263                                                  0                ...
#
#      arabic  arabic_speak_english_very_well  \
# 599       0                               0
# 161       0                               0
# 427       0                               0
# 261       0                               0
# 263       0                               0
#
#      arabic_speak_english_less_than_very_well  \
# 599                                         0
# 161                                         0
# 427                                         0
# 261                                         0
# 263                                         0
#
#      other_and_unspecified_languages  \
# 599                                0
# 161                                0
# 427                                0
# 261                                0
# 263                                0
#
#      other_and_unspecified_languages_speak_english_very_well  \
# 599                                                  0
# 161                                                  0
# 427                                                  0
# 261                                                  0
# 263                                                  0
#
#      other_and_unspecified_languages_speak_english_less_than_very_well  \
# 599                                                  0
# 161                                                  0
# 427                                                  0
# 261                                                  0
# 263                                                  0
#
#      statefp  countyfp  tractce  \
# 599       36       081   990100
# 161       36       081   091602
# 427       36       081   091603
# 261       36       081   055900
# 263       36       081   056500
#
#                                               geometry
# 599  POLYGON ((-73.93345 40.56691, -73.93336 40.566...
# 161  POLYGON ((-73.89554 40.56402, -73.89455 40.564...
# 427  POLYGON ((-73.93192 40.55782, -73.93178 40.557...
# 261  POLYGON ((-73.90422 40.69453, -73.9035 40.6952...
# 263  POLYGON ((-73.89889 40.69539, -73.89838 40.696...
#
# [5 rows x 42 columns]

# %%
# write some code to get rid of all the columns that have very_well in the name
cols = ['total',
        'speak_only_english',
        'spanish',
        'french_haitian_or_cajun',
        'german_or_other_west_germanic_languages',
        'russian_polish_or_other_slavic_languages',
        'other_indo_european_languages',
        'korean',
        'chinese_incl_mandarin_cantonese',
        'vietnamese',
        'tagalog_incl_filipino',
        'other_asian_and_pacific_island_languages',
        'arabic',
        'other_and_unspecified_languages',
        'statefp',
        'countyfp',
        'tractce',
        'geometry']

langs = df[cols].copy()
# create a list with new column names in
# don't change the order or number of columns from cols
new_cols = ['total',
            'english',
            'spanish',
            'french',
            'german',
            'russian',
            'other_european',
            'korean',
            'chinese',
            'vietnamese',
            'tagalog',
            'other_asian',
            'arabic',
            'other',
            'statefp',
            'countyfp',
            'tractce',
            'geometry']
langs.columns = new_cols

# %%
# get some data just for our map
map_data = langs.copy()
# create a new column for percent of spanish speakers
map_data["spanish_pct"] = round(map_data["spanish"] / map_data["total"] * 100)
# drop tracts with no data/no people
map_data = map_data[map_data["total"] > 0]
# make a choropleth showing the number of spanish speakers in a tract
base = ui.base_map(map_data, zoom=12)
map_data.explore(m=base, column='spanish_pct', tooltip="spanish_pct", cmap='Blues', legend=True)

# %%
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63e837c85dd92468b64258172c25b7ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63e837c85dd92468b64258172c25b7ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63e837c85dd92468b64258172c25b7ea = L.map(
#                 &quot;map_63e837c85dd92468b64258172c25b7ea&quot;,
#                 {
#                     center: [40.679441499999996, -73.8313945],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     name: &quot;&quot;,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_533abe030f046fc44448bf334c5858a2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;(C) OpenStreetMap contributors (C) CARTO&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_533abe030f046fc44448bf334c5858a2.addTo(map_63e837c85dd92468b64258172c25b7ea);
#
#
#         function geo_json_5abbb474e337521c6cdccea98137416b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;427&quot;: case &quot;124&quot;: case &quot;208&quot;: case &quot;182&quot;: case &quot;685&quot;: case &quot;181&quot;: case &quot;178&quot;: case &quot;173&quot;: case &quot;596&quot;: case &quot;468&quot;: case &quot;576&quot;: case &quot;318&quot;: case &quot;353&quot;: case &quot;326&quot;: case &quot;697&quot;: case &quot;677&quot;:
#                     return {&quot;color&quot;: &quot;#f5fafe&quot;, &quot;fillColor&quot;: &quot;#f5fafe&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;261&quot;: case &quot;529&quot;:
#                     return {&quot;color&quot;: &quot;#519ccc&quot;, &quot;fillColor&quot;: &quot;#519ccc&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;263&quot;: case &quot;384&quot;: case &quot;452&quot;: case &quot;129&quot;:
#                     return {&quot;color&quot;: &quot;#3888c1&quot;, &quot;fillColor&quot;: &quot;#3888c1&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;268&quot;:
#                     return {&quot;color&quot;: &quot;#3d8dc4&quot;, &quot;fillColor&quot;: &quot;#3d8dc4&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;264&quot;: case &quot;513&quot;: case &quot;684&quot;:
#                     return {&quot;color&quot;: &quot;#549fcd&quot;, &quot;fillColor&quot;: &quot;#549fcd&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;269&quot;: case &quot;209&quot;: case &quot;532&quot;: case &quot;514&quot;: case &quot;103&quot;: case &quot;588&quot;:
#                     return {&quot;color&quot;: &quot;#94c4df&quot;, &quot;fillColor&quot;: &quot;#94c4df&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;266&quot;: case &quot;652&quot;: case &quot;656&quot;:
#                     return {&quot;color&quot;: &quot;#75b4d8&quot;, &quot;fillColor&quot;: &quot;#75b4d8&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;272&quot;: case &quot;166&quot;: case &quot;483&quot;: case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;#a4cce3&quot;, &quot;fillColor&quot;: &quot;#a4cce3&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;162&quot;: case &quot;262&quot;: case &quot;438&quot;: case &quot;286&quot;: case &quot;180&quot;: case &quot;204&quot;: case &quot;547&quot;: case &quot;387&quot;: case &quot;225&quot;: case &quot;423&quot;:
#                     return {&quot;color&quot;: &quot;#f7fbff&quot;, &quot;fillColor&quot;: &quot;#f7fbff&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;523&quot;: case &quot;431&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;#3282be&quot;, &quot;fillColor&quot;: &quot;#3282be&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;565&quot;: case &quot;88&quot;: case &quot;628&quot;: case &quot;458&quot;: case &quot;280&quot;: case &quot;542&quot;:
#                     return {&quot;color&quot;: &quot;#8cc0dd&quot;, &quot;fillColor&quot;: &quot;#8cc0dd&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;213&quot;: case &quot;416&quot;: case &quot;502&quot;: case &quot;657&quot;: case &quot;1

# %%
url = f"https://api.census.gov/data/2022/acs/acs5?get=group(B15003)&ucgid=pseudo(0100000US$0400000)"
meta_url = "https://api.census.gov/data/2022/acs/acs5"

df = census_vars.get(url, meta_url)
df.head()
# Out:
#    state  state_name     total  no_schooling_completed  nursery_school  \
# 37    AK      Alaska    485871                    3875              58
# 22    AL     Alabama   3428520                   45445             624
# 39    AR    Arkansas   2031847                   27369             288
# 51    AZ     Arizona   4878959                   80113            1211
# 13    CA  California  26842698                  880931            8821
#
#     kindergarten  1st_grade  2nd_grade  3rd_grade  4th_grade  ...  \
# 37            29        109        261        517        446  ...
# 22           713        868       1823       4231       3206  ...
# 39           298        539       1529       3851       2964  ...
# 51          1394       2622       5446      10571       6186  ...
# 13         13922      31306      68837     144716      87564  ...
#
#     regular_high_school_diploma  ged_or_alternative_credential  \
# 37                       114087                          26039
# 22                       864977                         176748
# 39                       573876                         119999
# 51                       953769                         197611
# 13                      4837641                         647858
#
#     some_college_less_than_1_year  some_college_1_or_more_years_no_degree  \
# 37                          36099                                   85203
# 22                         219269                                  507480
# 39                         137651                                  299173
# 51                         369906                                  808921
# 13                        1592200                                 3816058
#
#     associate_s_degree  bachelor_s_degree  master_s_degree  \
# 37               43357              93744            39645
# 22              306021             572252           261039
# 39              159514             317437           134754
# 51              445866             958447           429317
# 13             2136258            5935292          2515475
#
#     professional_school_degree  doctorate_degree  \
# 37                        9589              6419
# 22                       56574             42980
# 39                       29822             19966
# 51                       93897             69793
# 13                      687281            488925
#
#                                              geometry
# 37  MULTIPOLYGON (((-179.23023 51.28393, -179.2256...
# 22  POLYGON ((-85.12733 31.76256, -85.12753 31.762...
# 39  POLYGON ((-90.95577 34.11871, -90.95451 34.117...
# 51  POLYGON ((-110.75069 37.00301, -110.74193 37.0...
# 13  MULTIPOLYGON (((-119.99987 41.18397, -119.9998...
#
# [5 rows x 28 columns]
