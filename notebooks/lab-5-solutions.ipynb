# %% [markdown]
# Lab 5: Metro Area Places
# ========================
# We are going to  apply the skills
# and techniques we have been developing
# and apply them to a new data set.
#
#
# - sorting data
# - selecting columns
# - filtering data
# - creating new columns with vector operations
# - creating new columns using the `apply()` method
# - creating interactive maps with `explore()`
# - plot points on a map
# - formatting and customizing tooltip and popup options
# - changing base tile maps
# - using colormaps to display data
#
# The data for this week includes all Census "places" in the New York
# metro area. A "place" is a city, town, village, or other census
# designated area.

# %%
# load the libraries
# these should be all that you need for the lab

# !pip install mapclassify -q
import pandas as pd
import geopandas as gpd
from IPython.display import display, HTML, Markdown as md
import xyzservices.providers as xyz
import folium
import math
import matplotlib.pyplot as plt
from matplotlib import colors

# %% [markdown]
# Problem 1: load the libraries and data
# ======================================
# Load the data from `url` into a `GeoDataFrame`.
# Show a random sample of 10 rows.

# %%
# load the URL into a geopandas GeoDataFrame
url = "https://raw.githubusercontent.com/mcuringa/cartopy/refs/heads/main/notebooks/data/metro_places.geojson"
df = gpd.read_file(url)
df.sample(10)
# Out:
#                  name  total_pop  population_under_18  median_inc  poverty  \
# 46      Poplar Plains       1431                  424      250001       36
# 187          Plandome       1365                  439      250001       54
# 175   Upper Montclair      12441                 3540      234620      270
# 12              Byram       5285                 1318       92500      252
# 108  Englewood Cliffs       5347                 1154      213261      120
# 9         Branchville         79                    0  -666666666        0
# 184     Valley Stream      40288                 7819      122048     1664
# 473          Setauket       3739                  952      218077      130
# 171            Singac       4253                  619       96467      148
# 13    Candlewood Isle        467                   98      250001        0
#
#      asian  black  indian  latino  mixed  other  pacific  white state  \
# 46      52      0       0     145     34     20        0   1180    CT
# 187     84      3       0      23     81      0        0   1174    NY
# 175    584    723       0     940    817     41       19   9317    NJ
# 12     106    239       0    2139     60     62        0   2679    CT
# 108   2290     97       0     511    254      0        5   2190    NJ
# 9        0      0       0       0      0      0        0     79    CT
# 184   6746  10249       0    9366   1623   1676        0  10628    NY
# 473    226     42       0     206     99     63        0   3103    NY
# 171    139     83       0    1350      0      0        0   2681    NJ
# 13       0      0       0      33      0      0        0    434    CT
#
#                   county                    geometry
# 46   Western Connecticut  POINT (-73.37711 41.17141)
# 187               Nassau  POINT (-73.69973 40.80694)
# 175                Essex  POINT (-74.20064 40.84327)
# 12   Western Connecticut    POINT (-73.6528 41.0012)
# 108               Bergen  POINT (-73.94672 40.88227)
# 9    Western Connecticut  POINT (-73.44337 41.26784)
# 184               Nassau  POINT (-73.70435 40.66464)
# 473              Suffolk  POINT (-73.11595 40.94841)
# 171              Passaic   POINT (-74.24297 40.8849)
# 13   Western Connecticut  POINT (-73.45229 41.47771)

# %% [markdown]
# Problem 2: Sort, filter, select
# ===============================
# Get a subset of the data that
# only shows places in Nassau County.
#
# Sort the data be median income (high to low),
# then display a table with only the
# name of the place, the total population, and the
# median income.
#
# Also:
#
# - give the columns nicer names
# - format population with commas
# - format median income as currency
# - `-666666666` indicates a missing value for `median_inc`, filter out those rows
#
# Display the first 10 rows and last 10 rows of the data.

# %%
nassau = df[(df.county == "Nassau") & (df.median_inc > 0)].copy()
nassau = nassau[["name", "total_pop", "median_inc"]].sort_values(by="median_inc", ascending=False)

def pop(x):
    return f"{x:,}"

def inc(x):
    return f"${x:,}"
nassau.total_pop = nassau.total_pop.apply(pop)
nassau.median_inc = nassau.median_inc.apply(inc)
nassau.columns = ["Place", "Population", "Median Income"]
display(md("## 10 wealthiest places in Nassau County"))
display(nassau.head(10))
display(md("## 10 poorest places in Nassau County"))
display(nassau.tail(10))
# Out:
# ## 10 wealthiest places in Nassau County
#                 Place Population Median Income
# 187          Plandome      1,365      $250,001
# 211    Roslyn Estates      1,350      $250,001
# 205  Plandome Heights        938      $250,001
# 204      Old Westbury      4,410      $250,001
# 223   Oyster Bay Cove      1,942      $250,001
# 228       Munsey Park      2,792      $250,001
# 218        Woodsburgh        887      $250,001
# 215       Sands Point      2,702      $250,001
# 295     Laurel Hollow      2,050      $250,001
# 301       Flower Hill      4,787      $250,001
# ## 10 poorest places in Nassau County
#                   Place Population Median Income
# 546  University Gardens      4,171      $104,844
# 500       Point Lookout      1,110      $104,386
# 292          Cedarhurst      7,307      $102,561
# 334            Bay Park      1,389      $100,972
# 210              Roslyn      2,928       $97,073
# 280    Great Neck Plaza      7,443       $97,022
# 285         Island Park      4,947       $96,875
# 306          Manorhaven      6,929       $95,493
# 281           Hempstead     58,557       $80,350
# 422              Inwood     11,156       $67,058

# %% [markdown]
# Problem 3: Plot the places on a map
# -----------------------------------
# Plot all of the places (not just Nassau County) on an
# interactive map. Use the `place` value for the tooltip.
# Use `place`, `total_pop`, and `median_inc` for the popup.

# %%
df.explore(popup=["name", "total_pop", "median_inc"], tooltip="name", tooltip_kwds={"labels": False})
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e14f017c04dfbecd85d6e54595be8d38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e14f017c04dfbecd85d6e54595be8d38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e14f017c04dfbecd85d6e54595be8d38 = L.map(
#                 &quot;map_e14f017c04dfbecd85d6e54595be8d38&quot;,
#                 {
#                     center: [41.11316096639163, -73.18851280630723],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e14f017c04dfbecd85d6e54595be8d38);
#
#
#
#
#
#             var tile_layer_9c649569c7a6e41f8f918c58c58034d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_9c649569c7a6e41f8f918c58c58034d2.addTo(map_e14f017c04dfbecd85d6e54595be8d38);
#
#
#             map_e14f017c04dfbecd85d6e54595be8d38.fitBounds(
#                 [[40.585341540667706, -74.43074106277771], [41.64098039211555, -71.94628454983675]],
#                 {}
#             );
#
#
#         function geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10 = L.geoJson(null, {
#                 onEachFeature: geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_onEachFeature,
#
#                 style: geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_styler,
#                 pointToLayer: geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_pointToLayer,
#         });
#
#         function geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_add (data) {
#             geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10
#                 .addData(data);
#         }
#             geo_json_e8ce49c6c3bed7d50e1f40d83a52ea10_add({&quot;bbox&quot;: [-74.43074106277771, 40.585341540667706, -71.94628454983675, 41.64098039211555], &quot;features&quot;: [{&quot;bbox&quot;: [-73.54979635576377, 41.07819506338073, -73.54979635576377, 41.0781

# %% [markdown]
# Problem 4: Colored points
# =========================
# In this problem you will separate the places
# into 3 DataFrames, one for each state.
#
# Plot them on the same map, using the following colors:
#
# - New York: blue
# - Connecticut: green
# - New Jersey: orange
#
# Show the map, use `name` and `state` in the tooltip,

# %%
ny = df[df.state == "NY"]
nj = df[df.state == "NJ"]
ct = df[df.state == "CT"]

m = ny.explore(tooltip=["name", "state"], style_kwds={"fillColor": "blue", "color":"blue", "fillOpacity": 1})   
nj.explore(m=m, tooltip=["name", "state"], style_kwds={"fillColor": "orange", "color":"orange", "fillOpacity": 1})   
ct.explore(m=m, tooltip=["name", "state"], style_kwds={"fillColor": "green", "color":"green", "fillOpacity": 1})   
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9547699ce3c08fc061bc363edc72d5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9547699ce3c08fc061bc363edc72d5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9547699ce3c08fc061bc363edc72d5e = L.map(
#                 &quot;map_d9547699ce3c08fc061bc363edc72d5e&quot;,
#                 {
#                     center: [41.02952274576057, -73.06825875866654],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_d9547699ce3c08fc061bc363edc72d5e);
#
#
#
#
#
#             var tile_layer_fbc0e28907cdb8c044701475d97f9bf9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fbc0e28907cdb8c044701475d97f9bf9.addTo(map_d9547699ce3c08fc061bc363edc72d5e);
#
#
#             map_d9547699ce3c08fc061bc363edc72d5e.fitBounds(
#                 [[40.585341540667706, -74.19023296749634], [41.47370395085344, -71.94628454983675]],
#                 {}
#             );
#
#
#         function geo_json_eb6fbe3b6ef8cdec81a37bfd939c1c52_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 1, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_eb6fbe3b6ef8cdec81a37bfd939c1c52_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_eb6fbe3b6ef8cdec81a37bfd939c1c52_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_eb6fbe3b6ef8cdec81a37bfd939c1c52_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_eb6fbe3b6ef8cdec81a37bfd939c1c52_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_eb6fbe3b6ef8cdec81a37bfd939c1c52.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_eb6fbe3b6ef8cdec81a37bfd939c1c52_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_eb6fbe3b6ef8cdec81a37bfd939c1c52 = L.geoJson(null, {
#                 onEachFeature: geo_json_eb6fbe3b6ef8cdec81a37bfd939c1c52_onEachFeature,

# %% [markdown]
# Problem 5: Median income colormap
# ---------------------------------
# Use a divergent colormap to plot the places on the map
# by median income. Use `name` and `median_inc` in the tooltip.
#
# - Filter out missing values (where median inc is at or below zero)
# - Format the median income as currency.

# %%
data = df.copy()
# filter out the missing values
data = data[data.median_inc > 0]

lower = data.median_inc.min()
upper = data.median_inc.max()
cmap = plt.get_cmap("seismic_r")
norm = colors.Normalize(vmin=lower, vmax=upper)


def get_color(pop_change):
    return colors.rgb2hex(cmap(norm(pop_change)))

data["color"] = data.median_inc.apply(get_color)

title = f"""
Median Income in NYC Metro Area
===============================
Poorer areas in red, wealthier areas in blue.
"""
display(md(title))

def mk_tooltip(row):
    return f"<b>{row["name"]}:</b> ${row.median_inc:,}"

data["tooltip"] = data.apply(mk_tooltip, axis=1)

data.explore(color=data['color'], tooltip="tooltip", tooltip_kwds={ "labels": False}, style_kwds={"radius": 5, "fillOpacity": .8})
# Out:
# Median Income in NYC Metro Area
# ===============================
# Poorer areas in red, wealthier areas in blue.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27aaf95eca3996e3f21b7cd77db84e62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27aaf95eca3996e3f21b7cd77db84e62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27aaf95eca3996e3f21b7cd77db84e62 = L.map(
#                 &quot;map_27aaf95eca3996e3f21b7cd77db84e62&quot;,
#                 {
#                     center: [41.11316096639163, -73.18851280630723],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_27aaf95eca3996e3f21b7cd77db84e62);
#
#
#
#
#
#             var tile_layer_c1043a02e4e260bf99240e5027dd6ff5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c1043a02e4e260bf99240e5027dd6ff5.addTo(map_27aaf95eca3996e3f21b7cd77db84e62);
#
#
#             map_27aaf95eca3996e3f21b7cd77db84e62.fitBounds(
#                 [[40.585341540667706, -74.43074106277771], [41.64098039211555, -71.94628454983675]],
#                 {}
#             );
#
#
#         function geo_json_16aea0ca6431b89a3b34f1f34f7f04ba_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;238&quot;: case &quot;334&quot;: case &quot;373&quot;:
#                     return {&quot;color&quot;: &quot;#ff5151&quot;, &quot;fillColor&quot;: &quot;#ff5151&quot;, &quot;fillOpacity&quot;: 0.8, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;: case &quot;86&quot;: case &quot;138&quot;: case &quot;170&quot;: case &quot;179&quot;: case &quot;281&quot;: case &quot;459&quot;:
#                     return {&quot;color&quot;: &quot;#f80000&quot;, &quot;fillColor&quot;: &quot;#f80000&quot;, &quot;fillOpacity&quot;: 0.8, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;17&quot;: case &quot;178&quot;: case &quot;202&quot;: case &quot;245&quot;: case &quot;312&quot;: case &quot;480&quot;:
#                     return {&quot;color&quot;: &quot;#e5e5ff&quot;, &quot;fillColor&quot;: &quot;#e5e5ff&quot;, &quot;fillOpacity&quot;: 0.8, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;210&quot;:
#                     return {&quot;color&quot;: &quot;#ff4141&quot;, &quot;fillColor&quot;: &quot;#ff4141&quot;, &quot;fillOpacity&quot;: 0.8, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;354&quot;: case &quot;372&quot;: case &quot;374&quot;: case &quot;413&quot;:
#                     return {&quot;color&quot;: &quot;#fffdfd&quot;, &quot;fillColor&quot;: &quot;#fffdfd&quot;, &quot;fillOpacity&quot;: 0.8, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;120&quot;: case &quot;135&quot;: case &quot;255&quot;: case &quot;389&quot;:
#                     return {&quot;color&quot;: &quot;#f60000&quot;, &quot;fillColor&quot;: &quot;#f60000&quot;, &quot;fillOpacity&quot;: 0.8, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;87&quot;: case &quot;399&quot;: case &quot;423&quot;: case &quot;493&quot;:
#                     return {&quot;color&quot;: &quot;#ffa5a5&quot;, &quot;fillColor&quot;: &quot;#ffa5a5&quot;, &quot;fillOpacity&quot;: 0.8, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#000068&quot;, &quot;fillColor&quot;: &quot;#000068&quot;, &quot;fillOpacity&quot;: 0.8, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;13&quot;: case &quot;15&quot;: case &quot;18&quot;: case &quot;28&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;44&quot;: case &quot;46&quot;: case &quot;50&quot;: case &quot;53&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;83&quot;: case &quot;169&quot;: case &quot;187&quot;: case &quot;204&quot;: case &quot;205&quot;: case &quot;211&quot;: case &quot;215&quot;: case &quot;218&quot;: case &quot;223&quot;: case &quot;228&quot;: case &quot;240&quot;: case &quot;256&quot;: case &quot;264&quot;: case &quot;276&quot;: case &quot;282&quot;: case &quot;283&quot;: case &quot;284&quot;: case &quot;286&quot;: case &quot;289&quot;: case &quot;295&quot;: ca

# %% [markdown]
# Problem 6: Racial/Ethnic Plurality by place
# ============================================
# Working form last week's demonstration
# of creating a categorical color map from racial
# pluralities, make a similar map with our data set.
#
# The map can be an exact copy of the demo one from lab 4,
# with the following additions/changes:
#
# - filter out all data with zero population
# - use `name` as the tooltip
# - create a new column for the popup:
#   - use markdown to format the popup
#   - show the **percentages** of each ethnicity in the popup
#
# Example of popup:
#
# <b>New York City</b><br>
# <br>
# Asian: 14.36%<br>
# Black/African American: 21.00%<br>
# Hispanic/Latinx: 29.03%<br>
# White: 31.16%<br>
# American Indian: 0.18%<br>
# Pacific Island: 0.04%<br>
# Mixed: 3.09%<br>
# Other: 1.14%<br>
#
# _Note: put <br> at the end of the line to force a line break in the popup._

# %%
# let's make a categorical map showing which racial/ethnic group
# have a plurality in each city

data = df.copy()
data = data[data.total_pop > 0]

# we have these categories in our columns
# this dict maps the column name to a numerical category
ethnic_cats = {
    'asian': 0,
    'black': 1,
    'latino': 2,
    'white': 3
}

def get_plurality(row):
    max_cat = row[["asian", "black", "latino", "white"]].idxmax()
    return max_cat

data["plurality"] = data.apply(get_plurality, axis=1)

# tab10 has 10 distinct colors
cmap = plt.get_cmap('tab10')

def get_color(plurality):
    category_number = ethnic_cats[plurality]
    return colors.rgb2hex(cmap(category_number))

data["color"] = data.plurality.apply(get_color)


def mk_popup(row):
    pop = f"""<b>{row["name"]}</b><br>
<br>
Asian: {(row.asian / row.total_pop) * 100:.2f}%<br>
Black/African American: {(row.black / row.total_pop) * 100:.2f}%<br>
Hispanic/Latinx: {(row.latino / row.total_pop) * 100:.2f}%<br>
White: {(row.white / row.total_pop) * 100:.2f}%<br>
American Indian: {(row.indian / row.total_pop) * 100:.2f}%<br>
Pacific Island: {(row.pacific / row.total_pop) * 100:.2f}%<br>
Mixed: {(row.mixed / row.total_pop) * 100:.2f}%<br>
Other: {(row.other / row.total_pop) * 100:.2f}%<br>
"""
    return pop

data["popup"] = data.apply(mk_popup, axis=1)

legend_data = {
    'Asian/Pacific Islander': colors.rgb2hex(cmap(0)),
    'Black/African American': colors.rgb2hex(cmap(1)),
    'Latinx/Chicanx/Hispanic': colors.rgb2hex(cmap(2)),
    f'White{"&nbsp;"*20}': colors.rgb2hex(cmap(3))
}
legend_df = pd.DataFrame([legend_data])
legend = legend_df.style.apply(lambda row: [f'background-color: {color}' for color in row], axis=0)

title = f"""
Racial/ethnic pluralities
=================================================
"""
display(md(title))
display(legend)

data.explore(color=data['color'], tooltip="name", popup="popup", style_kwds={"radius": 5, "fillOpacity": .8})
# Out:
# Racial/ethnic pluralities
# =================================================
# <style type="text/css">
# #T_08dc1_row0_col0 {
#   background-color: #1f77b4;
# }
# #T_08dc1_row0_col1 {
#   background-color: #ff7f0e;
# }
# #T_08dc1_row0_col2 {
#   background-color: #2ca02c;
# }
# #T_08dc1_row0_col3 {
#   background-color: #d62728;
# }
# </style>
# <table id="T_08dc1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08dc1_level0_col0" class="col_heading level0 col0" >Asian/Pacific Islander</th>
#       <th id="T_08dc1_level0_col1" class="col_heading level0 col1" >Black/African American</th>
#       <th id="T_08dc1_level0_col2" class="col_heading level0 col2" >Latinx/Chicanx/Hispanic</th>
#       <th id="T_08dc1_level0_col3" class="col_heading level0 col3" >White&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08dc1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08dc1_row0_col0" class="data row0 col0" >#1f77b4</td>
#       <td id="T_08dc1_row0_col1" class="data row0 col1" >#ff7f0e</td>
#       <td id="T_08dc1_row0_col2" class="data row0 col2" >#2ca02c</td>
#       <td id="T_08dc1_row0_col3" class="data row0 col3" >#d62728</td>
#     </tr>
#   </tbody>
# </table>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee9853ef8fc0a46795ef6f334925d15c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee9853ef8fc0a46795ef6f334925d15c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee9853ef8fc0a46795ef6f334925d15c = L.map(
#                 &quot;map_ee9853ef8fc0a46795ef6f334925d15c&quot;,
#                 {
#                     center: [41.11316096639163, -73.18851280630723],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_ee9853ef8fc0a46795ef6f334925d15c);
#
#
#
#
#
#             var tile_layer_fd6ed749ecc451b56e61ce1f43768953 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_fd6ed749ecc451b56e61ce1f43768953.addTo(map_ee9853ef8fc0a46795ef6f334925d15c);
#
#
#             map_ee9853ef8fc0a46795ef6f334925d15c.fitBounds(
#                 [[40.585341540667706, -74.43074106277771], [41.64098039211555, -71.94628454983675]],
#                 {}
#             );
#
#
#         function geo_json_942b01c02b13660bbccfde6347860a7b_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;32&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;47&quot;: case &quot;48&quot;: case &quot;49&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;52&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;65&quot;: case &quot;66&quot;: case &quot;67&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;70&quot;: case &quot;72&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;85&quot;: case &quot;86&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;89&quot;: case &quot;90&quot;: case &quot;91&quot;: case &quot;92&quot;: case &quot;93&quot;: case &quot;94&quot;: case &quot;95&quot;: case &quot;96&quot;: case &quot;97&quot;: case &quot;98&quot;: case &quot;100&quot;: case &quot;101&quot;: case &quot;103&quot;: case &quot;104&quot;: case &quot;105&quot;: case &quot;107&quot;: case &quot;111&quot;: case &quot;112&quot;: case &quot;114&quot;: case &quot;115&quot;: case &quot;116&quot;: case &quot;117&quot;: case &quot;118&quot;: case &quot;119&quot;: case &quot;121&quot;: case &quot;122&quot;: case &quot;124&quot;: case &quot;125&quot;: case &quot;127&quot;: case &quot;130&quot;: case &quot;131&quot;: case &quot;133&quot;: case &quot;134&quot;: case &quot;135&quot;: case &quot;136&quot;: case &quot;137&quot;: case &quot;138&quot;: case &quot;141&quot;: case &quot;144&quot;: case &quot;145&quot;: case &quot;147&quot;: case &quot;148&quot;: case &quot;149&quot;: ca

# %% [markdown]
# Bonus Problem: Plot population on a log scale
# =============================================
# Population size in our data set
# varies widely from a handful of people in
# small towns on Fire Island, to NYC
# with more than 8 million people. Most of the places
# are clustered at the lower end of the scale. If we
# use a sequential color map, almost all of the places
# are white or very faint.
#
# This means we can't meaningfully use a sequential
# color scale to get a sense of how place
# size varies in the region. One way to
# get a better sense is to use a logarithmic
# scale rather than a linear scale.
#
# Try this:
#
# - filter out NYC (it's still too big)
# - filter out all of the zerop popluation towns
# - create a new column called `log_pop` and set it to the math.log() of total_pop
# - plot `log_pop` on the map, using a sequential colormap of your choice

# %%
# copy the data and filter out NYC
data = df.copy()
data = data[(data.total_pop < 500_000) & (data.total_pop > 0)]
# data = data[data.total_pop > 0]

data["pop_log"] = data.total_pop.apply(math.log2)
lower = data.pop_log.min()
upper = data.pop_log.max()

# use the "coolwarm" color map from matplotlib
cmap = plt.get_cmap("Purples")
norm = colors.Normalize(vmin=lower, vmax=upper)


def get_color(pop_change):
    return colors.rgb2hex(cmap(norm(pop_change)))


data["color"] = data.pop_log.apply(get_color)


title = f"""
Place size New York Metro Area
=================================================
"""
display(md(title))

# make a tooltip with both the population change percentage and the number of people


def mk_tooltip(row):
    return f"<b>{row['name']}:</b> {row.total_pop:,} people."


data["tooltip"] = data.apply(mk_tooltip, axis=1)


data.explore(color=data['color'], tooltip="tooltip", tooltip_kwds={"labels": False}, style_kwds={"radius": 5, "fillOpacity": 1})
# Out:
# Place size New York Metro Area
# =================================================
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37924d28ac9bd5c3a3821630842df009 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37924d28ac9bd5c3a3821630842df009&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37924d28ac9bd5c3a3821630842df009 = L.map(
#                 &quot;map_37924d28ac9bd5c3a3821630842df009&quot;,
#                 {
#                     center: [41.11316096639163, -73.18851280630723],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_37924d28ac9bd5c3a3821630842df009);
#
#
#
#
#
#             var tile_layer_f13f68fac7fe432d474d816fe7db542a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f13f68fac7fe432d474d816fe7db542a.addTo(map_37924d28ac9bd5c3a3821630842df009);
#
#
#             map_37924d28ac9bd5c3a3821630842df009.fitBounds(
#                 [[40.585341540667706, -74.43074106277771], [41.64098039211555, -71.94628454983675]],
#                 {}
#             );
#
#
#         function geo_json_8b3d8edc086c0bb615dfa0e4de074bcf_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;#4a1587&quot;, &quot;fillColor&quot;: &quot;#4a1587&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;#51218c&quot;, &quot;fillColor&quot;: &quot;#51218c&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;2&quot;: case &quot;223&quot;: case &quot;224&quot;: case &quot;329&quot;: case &quot;408&quot;:
#                     return {&quot;color&quot;: &quot;#8c88bf&quot;, &quot;fillColor&quot;: &quot;#8c88bf&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;: case &quot;77&quot;:
#                     return {&quot;color&quot;: &quot;#50208c&quot;, &quot;fillColor&quot;: &quot;#50208c&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;4&quot;: case &quot;158&quot;: case &quot;221&quot;: case &quot;255&quot;: case &quot;268&quot;: case &quot;350&quot;: case &quot;454&quot;: case &quot;520&quot;:
#                     return {&quot;color&quot;: &quot;#8683bd&quot;, &quot;fillColor&quot;: &quot;#8683bd&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;: case &quot;78&quot;: case &quot;114&quot;: case &quot;128&quot;: case &quot;151&quot;: case &quot;198&quot;: case &quot;245&quot;: case &quot;455&quot;: case &quot;491&quot;:
#                     return {&quot;color&quot;: &quot;#6e5aa8&quot;, &quot;fillColor&quot;: &quot;#6e5aa8&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;6&quot;: case &quot;205&quot;: case &quot;262&quot;:
#                     return {&quot;color&quot;: &quot;#9b97c6&quot;, &quot;fillColor&quot;: &quot;#9b97c6&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;7&quot;:
#                     return {&quot;color&quot;: &quot;#babadb&quot;, &quot;fillColor&quot;: &quot;#babadb&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;59&quot;: case &quot;103&quot;: case &quot;269&quot;: case &quot;443&quot;: case &quot;550&quot;:
#                     return {&quot;color&quot;: &quot;#a4a1cc&quot;, &quot;fillColor&quot;: &quot;#a4a1cc&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;9&quot;:
#                     return {&quot;color&quot;: &quot;#cdcde4&quot;, &quot;fillColor&quot;: &quot;#cdcde4&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;10&quot;: case &quot;15&quot;: case &quot;53&quot;:
#                     return {&quot;color&quot;: &quot;#c0c1de&quot;, &quot;fillColor&quot;: &quot;#c0c1de&quot;, &quot;fillOpacity&quot;: 1, &quot;radius&quot;: 5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;14&quot;:
#                     return {&quot;c
