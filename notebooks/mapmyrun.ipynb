# %% [markdown]
# Adelphi Campus Map
# ===================
#
# Load initial data
# -----------------
# This section loads the required python libraries
# that we need and loads the data from our files.
#
# It also declares some helper **functions** that
# will make it easier to work with your maps
# and the data.

# %%
# !pip install mapclassify -q

import geopandas as gpd
import folium
import xyzservices.providers as xyz
from IPython.display import display, HTML

campus_cols = ["key", "building", "title", "description", "color"]
campus = gpd.read_file("data/campus.geojson")
campus = campus.to_crs(epsg=4326)

def label_shapes(m, df, col, style={}):
    """Create a function that will add the string of `col`
    to the center of each shape in df """
    style_str = ";".join([f"{k}:{v}" for k, v in style.items()])

    def label(row):
        point = row.geometry.centroid
        html = f"""<div style="{style_str}">{row[col]}</div>"""
        folium.Marker(
            location=(point.y, point.x),
            icon=folium.DivIcon(html=html)).add_to(m)
    df.apply(label, axis=1)
    return m
# Out:
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
# show the campus map with labels
x = campus.explore(tooltip=False, popup="building")
x = label_shapes(x, campus, "key", style={"font-weight": "bold", "font-size": "14px"})
x
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35435030c28806b7dc2702e55310515f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35435030c28806b7dc2702e55310515f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35435030c28806b7dc2702e55310515f = L.map(
#                 &quot;map_35435030c28806b7dc2702e55310515f&quot;,
#                 {
#                     center: [40.719886243968446, -73.65201239756493],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_35435030c28806b7dc2702e55310515f);
#
#
#
#
#
#             var tile_layer_97dc261967068ac81baac760cdbf46cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_97dc261967068ac81baac760cdbf46cb.addTo(map_35435030c28806b7dc2702e55310515f);
#
#
#             map_35435030c28806b7dc2702e55310515f.fitBounds(
#                 [[40.71710518289702, -73.65506504272668], [40.72266730503987, -73.6489597524032]],
#                 {}
#             );
#
#
#         function geo_json_30b6cf7afc5c9192e886d752f2fa01c5_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_30b6cf7afc5c9192e886d752f2fa01c5_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_30b6cf7afc5c9192e886d752f2fa01c5_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_30b6cf7afc5c9192e886d752f2fa01c5_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_30b6cf7afc5c9192e886d752f2fa01c5_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_30b6cf7afc5c9192e886d752f2fa01c5.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_30b6cf7afc5c9192e886d752f2fa01c5_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_30b6cf7afc5c9192e886d752f2fa01c5 = L.geoJson(null, {
#                 onEachFeature: geo_json_30b6cf7afc5c9192e886d752f2fa01c5_onEachFeature,
#
#                 style: geo_json_30b6cf7afc5c9192e886d752f2fa01c5_styler,
#                 pointToLayer: geo_json_30b6cf7afc5c9192e886d752f2fa01c5_pointToLayer,
#         });
#
#         function geo_json_30b6cf7afc5c9192e886d752f2fa01c5_add (data) {
#             geo_json_30b6cf7afc5c9192e886d752f2fa01c5
#                 .addData(data);
#         }
#             geo_json_30b6cf7afc5c9192e886d752f2fa01c5_add({&quot;bbox&quot;: [-73.65506504272668, 40.71710518289702, -73.6489597524032, 40.72266730503987], &quot;features&quot;: [{&quot;bbox&quot;: [-73.6526021992346, 40.72260055356348, -73.65256109665151, 40.72266730503987], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-73.6526021992346, 40.72266730503987], [-73.6526021992346, 40.72260055356348], [-73.65256109665151, 40.72260055356348], [-73.65256109665151, 40.72266730503987], [-73.6526021992346, 40.72266730503987]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;building&quot;: &quot;Public Safety Booth&quot;, &quot;color&quot;: &quot;violet&quot;, &quot;description&quot;: &quot;Public Safety Booth (PSB)&quot;, &quot;key&quot;: &

# %% [markdown]
# The campus buildings
# --------------------
# We loaded the campus map data into a `pandas` `DataFrame`
# called **campus**. It has interactive shapes with all of the
# buildings. Here you can change the colors of the buildings,
# the tooltip "title" (what you see when you mouse over the building)
# and the popup "description" (what you see when you click on the building).
#
# When you run the code block below, you will see a table
# with your data. Once you are satisfied with the data,
# run the next code block to see it on a map.
#
# To change the building colors, you can use any
# [named color](https://developer.mozilla.org/en-US/docs/Web/CSS/named-color)
# or [color hex code](https://developer.mozilla.org/en-US/docs/Web/CSS/hex-color)

# %%
# Change the building colors
colors = {
    'PSB': 'violet',
    'GMB': 'violet',
    'EHB': 'violet',
    'AHE': 'violet',
    'HWC': 'violet',
    'NEX': 'violet',
    'LVM': 'violet',
    'SWL': 'violet',
    'SCB': 'violet',
    'BLH': 'violet',
    'UNC': 'violet',
    'RHA': 'violet',
    'RHB': 'violet',
    'EDH': 'violet',
    'LNH': 'violet',
    'CHH': 'violet',
    'SWB': 'violet',
    'HHE': 'crimson',
    'PAC': 'violet',
    'WLH': 'violet',
    'HRH': 'violet',
    'ALH': 'violet',
    'ELC': 'violet',
    'EHA': 'violet',
    'CRS': 'violet',
    'WDH': 'violet',
    'PSH': 'violet',
    'KFA': 'violet'
}

# change the mouse hover titles
titles = {
    'PSB': 'Public Safety Booth (PSB)',
    'GMB': 'Grounds Maintenance Building (GMB)',
    'EHB': 'Earle Hall B (EHB)',
    'AHE': 'Alumni House (AHE)',
    'HWC': 'Hy Weinberg Center (HWC)',
    'NEX': 'Nexus Building (NEX)',
    'LVM': 'Levermore Hall (LVM)',
    'SWL': 'Swirbul Library (SWL)',
    'SCB': 'Science Building (SCB)',
    'BLH': 'Blodgett Hall (BLH)',
    'UNC': 'University Center (UNC)',
    'RHA': 'Residence Hall A (RHA)',
    'RHB': 'Residence Hall B (RHB)',
    'EDH': 'Eddy Hall (EDH)',
    'LNH': 'Linen Hall (LNH)',
    'CHH': 'Chapman Hall (CHH)',
    'SWB': 'Social Work Building (SWB)',
    'HHE': 'Hagedorn Hall of Enterprise (HHE)',
    'PAC': 'Performing Arts Center (PAC)',
    'WLH': 'Waldo Hall (WLH)',
    'HRH': 'Harvey Hall (HRH)',
    'ALH': 'Alumnae Hall (ALH)',
    'ELC': 'Early Learning Center (ELC)',
    'EHA': 'Earle Hall A (EHA)',
    'CRS': 'Center for Recreation & Sport (CRS)',
    'WDH': 'Woodruff Hall (WDH)',
    'PSH': 'Post Hall (PSH)',
    'KFA': 'Adele & Herbert J. Klapper Center for Fine Arts (KFA)'
}

# change the popup descriptions
descriptions = {
    "PSB": 
          """
          Public Safety Booth (PSB)
          """,
    "GMB": 
          """
          Grounds Maintenance Building (GMB)
          """,
    "EHB": 
          """
          Earle Hall B (EHB)
          """,
    "AHE": 
          """
          Alumni House (AHE)
          """,
    "HWC": 
          """
          Hy Weinberg Center (HWC)
          """,
    "NEX": 
          """
          Nexus Building (NEX)
          """,
    "LVM": 
          """
          Levermore Hall (LVM)
          """,
    "SWL": 
          """
          Swirbul Library (SWL)
          """,
    "SCB": 
          """
          Science Building (SCB)
          """,
    "BLH": 
          """
          Blodgett Hall (BLH)
          """,
    "UNC": 
          """
          University Center (UNC)
          """,
    "RHA": 
          """
          Residence Hall A (RHA)
          """,
    "RHB": 
          """
          Residence Hall B (RHB)
          """,
    "EDH": 
          """
          Eddy Hall (EDH)
          """,
    "LNH": 
          """
          Linen Hall (LNH)
          """,
    "CHH": 
          """
          Chapman Hall (CHH)
          """,
    "SWB": 
          """
          Social Work Building (SWB)
          """,
    "HHE": 
          """
          Hagedorn Hall of Enterprise
          The site of our FYS.
          """,
    "PAC": 
          """
          Performing Arts Center (PAC)
          """,
    "WLH": 
          """
          Waldo Hall (WLH)
          """,
    "HRH": 
          """
          Harvey Hall (HRH)
          """,
    "ALH": 
          """
          Alumnae Hall (ALH)
          """,
    "ELC": 
          """
          Early Learning Center (ELC)
          """,
    "EHA": 
          """
          Earle Hall A (EHA)
          """,
    "CRS": 
          """
          Center for Recreation & Sport (CRS)
          """,
    "WDH": 
          """
          Woodruff Hall (WDH)
          """,
    "PSH": 
          """
          Post Hall (PSH)
          """,
    "KFA": 
          """
          Adele & Herbert J. Klapper Center for Fine Arts (KFA
          """
}
# update the colors with new data
campus.color = campus.apply(lambda x: colors[x.key], axis=1)

# update the titles with new data
campus.title = campus.apply(lambda x: titles[x.key], axis=1)

# update the descriptions with new data
campus.description = campus.apply(lambda x: descriptions[x.key], axis=1)

# format the table with the colored background
table = campus[campus_cols].style.apply(lambda x: [f'background-color: {v}' if x.name == 'color' else '' for v in x], axis=0)

# show the table
table
# Out:
# <style type="text/css">
# #T_13103_row0_col4, #T_13103_row1_col4, #T_13103_row2_col4, #T_13103_row3_col4, #T_13103_row4_col4, #T_13103_row5_col4, #T_13103_row6_col4, #T_13103_row7_col4, #T_13103_row8_col4, #T_13103_row9_col4, #T_13103_row10_col4, #T_13103_row11_col4, #T_13103_row12_col4, #T_13103_row13_col4, #T_13103_row14_col4, #T_13103_row15_col4, #T_13103_row16_col4, #T_13103_row18_col4, #T_13103_row19_col4, #T_13103_row20_col4, #T_13103_row21_col4, #T_13103_row22_col4, #T_13103_row23_col4, #T_13103_row24_col4, #T_13103_row25_col4, #T_13103_row26_col4, #T_13103_row27_col4 {
#   background-color: violet;
# }
# #T_13103_row17_col4 {
#   background-color: crimson;
# }
# </style>
# <table id="T_13103">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13103_level0_col0" class="col_heading level0 col0" >key</th>
#       <th id="T_13103_level0_col1" class="col_heading level0 col1" >building</th>
#       <th id="T_13103_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_13103_level0_col3" class="col_heading level0 col3" >description</th>
#       <th id="T_13103_level0_col4" class="col_heading level0 col4" >color</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13103_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13103_row0_col0" class="data row0 col0" >PSB</td>
#       <td id="T_13103_row0_col1" class="data row0 col1" >Public Safety Booth</td>
#       <td id="T_13103_row0_col2" class="data row0 col2" >Public Safety Booth (PSB)</td>
#       <td id="T_13103_row0_col3" class="data row0 col3" >
#           Public Safety Booth (PSB)
#           </td>
#       <td id="T_13103_row0_col4" class="data row0 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13103_row1_col0" class="data row1 col0" >GMB</td>
#       <td id="T_13103_row1_col1" class="data row1 col1" >Grounds Maintenance Building</td>
#       <td id="T_13103_row1_col2" class="data row1 col2" >Grounds Maintenance Building (GMB)</td>
#       <td id="T_13103_row1_col3" class="data row1 col3" >
#           Grounds Maintenance Building (GMB)
#           </td>
#       <td id="T_13103_row1_col4" class="data row1 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13103_row2_col0" class="data row2 col0" >EHB</td>
#       <td id="T_13103_row2_col1" class="data row2 col1" >Earle Hall B</td>
#       <td id="T_13103_row2_col2" class="data row2 col2" >Earle Hall B (EHB)</td>
#       <td id="T_13103_row2_col3" class="data row2 col3" >
#           Earle Hall B (EHB)
#           </td>
#       <td id="T_13103_row2_col4" class="data row2 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13103_row3_col0" class="data row3 col0" >AHE</td>
#       <td id="T_13103_row3_col1" class="data row3 col1" >Alumni House</td>
#       <td id="T_13103_row3_col2" class="data row3 col2" >Alumni House (AHE)</td>
#       <td id="T_13103_row3_col3" class="data row3 col3" >
#           Alumni House (AHE)
#           </td>
#       <td id="T_13103_row3_col4" class="data row3 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13103_row4_col0" class="data row4 col0" >HWC</td>
#       <td id="T_13103_row4_col1" class="data row4 col1" >Hy Weinberg Center</td>
#       <td id="T_13103_row4_col2" class="data row4 col2" >Hy Weinberg Center (HWC)</td>
#       <td id="T_13103_row4_col3" class="data row4 col3" >
#           Hy Weinberg Center (HWC)
#           </td>
#       <td id="T_13103_row4_col4" class="data row4 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13103_row5_col0" class="data row5 col0" >NEX</td>
#       <td id="T_13103_row5_col1" class="data row5 col1" >Nexus Building</td>
#       <td id="T_13103_row5_col2" class="data row5 col2" >Nexus Building (NEX)</td>
#       <td id="T_13103_row5_col3" class="data row5 col3" >
#           Nexus Building (NEX)
#           </td>
#       <td id="T_13103_row5_col4" class="data row5 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_13103_row6_col0" class="data row6 col0" >LVM</td>
#       <td id="T_13103_row6_col1" class="data row6 col1" >Levermore Hall</td>
#       <td id="T_13103_row6_col2" class="data row6 col2" >Levermore Hall (LVM)</td>
#       <td id="T_13103_row6_col3" class="data row6 col3" >
#           Levermore Hall (LVM)
#           </td>
#       <td id="T_13103_row6_col4" class="data row6 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_13103_row7_col0" class="data row7 col0" >SWL</td>
#       <td id="T_13103_row7_col1" class="data row7 col1" >Swirbul Library</td>
#       <td id="T_13103_row7_col2" class="data row7 col2" >Swirbul Library (SWL)</td>
#       <td id="T_13103_row7_col3" class="data row7 col3" >
#           Swirbul Library (SWL)
#           </td>
#       <td id="T_13103_row7_col4" class="data row7 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_13103_row8_col0" class="data row8 col0" >SCB</td>
#       <td id="T_13103_row8_col1" class="data row8 col1" >Science Building</td>
#       <td id="T_13103_row8_col2" class="data row8 col2" >Science Building (SCB)</td>
#       <td id="T_13103_row8_col3" class="data row8 col3" >
#           Science Building (SCB)
#           </td>
#       <td id="T_13103_row8_col4" class="data row8 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_13103_row9_col0" class="data row9 col0" >BLH</td>
#       <td id="T_13103_row9_col1" class="data row9 col1" >Blodgett Hall</td>
#       <td id="T_13103_row9_col2" class="data row9 col2" >Blodgett Hall (BLH)</td>
#       <td id="T_13103_row9_col3" class="data row9 col3" >
#           Blodgett Hall (BLH)
#           </td>
#       <td id="T_13103_row9_col4" class="data row9 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_13103_row10_col0" class="data row10 col0" >UNC</td>
#       <td id="T_13103_row10_col1" class="data row10 col1" >University Center</td>
#       <td id="T_13103_row10_col2" class="data row10 col2" >University Center (UNC)</td>
#       <td id="T_13103_row10_col3" class="data row10 col3" >
#           University Center (UNC)
#           </td>
#       <td id="T_13103_row10_col4" class="data row10 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_13103_row11_col0" class="data row11 col0" >RHA</td>
#       <td id="T_13103_row11_col1" class="data row11 col1" >Residence Hall A</td>
#       <td id="T_13103_row11_col2" class="data row11 col2" >Residence Hall A (RHA)</td>
#       <td id="T_13103_row11_col3" class="data row11 col3" >
#           Residence Hall A (RHA)
#           </td>
#       <td id="T_13103_row11_col4" class="data row11 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_13103_row12_col0" class="data row12 col0" >RHB</td>
#       <td id="T_13103_row12_col1" class="data row12 col1" >Residence Hall B</td>
#       <td id="T_13103_row12_col2" class="data row12 col2" >Residence Hall B (RHB)</td>
#       <td id="T_13103_row12_col3" class="data row12 col3" >
#           Residence Hall B (RHB)
#           </td>
#       <td id="T_13103_row12_col4" class="data row12 col4" >violet</td>
#     </tr>
#     <tr>
#       <th id="T_13103_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_13103_row13_col0" class="data row13 col0" >EDH</td>
#       <td id="T_13103_row13_col1" class="data row13 col1" >Eddy Hall</td>
#       <td id="T_13103_row13_col2" c

# %% [markdown]
# Show the campus map
# -------------------
# Run the code block below to see the campus map.
# After you make changes to the data, run this code
# again to see the changes on the map.

# %%
campus_map = campus.explore(color="color", 
                            tooltip="title", 
                            tooltip_kwds={"labels": False}, 
                            style_kwds={"fillOpacity": 1, "opacity":0},
                            popup_kwds={"labels": False}, 
                            popup="description")

campus_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2cb9b75d6fa3ba2385055f59594aece {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2cb9b75d6fa3ba2385055f59594aece&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2cb9b75d6fa3ba2385055f59594aece = L.map(
#                 &quot;map_e2cb9b75d6fa3ba2385055f59594aece&quot;,
#                 {
#                     center: [40.719886243968446, -73.65201239756493],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e2cb9b75d6fa3ba2385055f59594aece);
#
#
#
#
#
#             var tile_layer_7175c19f84987b374603ad8cc6c11172 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7175c19f84987b374603ad8cc6c11172.addTo(map_e2cb9b75d6fa3ba2385055f59594aece);
#
#
#             map_e2cb9b75d6fa3ba2385055f59594aece.fitBounds(
#                 [[40.71710518289702, -73.65506504272668], [40.72266730503987, -73.6489597524032]],
#                 {}
#             );
#
#
#         function geo_json_1d7f3303f6da700ecb90e5e2002de45f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;:
#                     return {&quot;fillColor&quot;: &quot;violet&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 0, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 0, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1d7f3303f6da700ecb90e5e2002de45f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1d7f3303f6da700ecb90e5e2002de45f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_1d7f3303f6da700ecb90e5e2002de45f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1d7f3303f6da700ecb90e5e2002de45f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1d7f3303f6da700ecb90e5e2002de45f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1d7f3303f6da700ecb90e5e2002de45f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });

# %% [markdown]
# Load the running data
# ---------------------
#
# For this, you will need to download the running data from Discord
# and then upload it to your Colab.
#
# Here we're going to load the running data.
# We will show the table which holds the colored
# keys for each person.

# %%
# read in the running map data
data = gpd.read_file("../_data/runs.geojson")

# show the running table
table = data[["runner", "color"]].drop_duplicates().style.apply(lambda x: [f'background-color: {v}' if x.name == 'color' else '' for v in x], axis=0)
display(table)

# plot the running map on top of our campus map
running_map = data.explore(m=campus_map, color=data.color, tooltip="runner")
running_map
# Out:
# <style type="text/css">
# #T_55b22_row0_col1 {
#   background-color: #1f77b4;
# }
# #T_55b22_row1_col1 {
#   background-color: #aec7e8;
# }
# #T_55b22_row2_col1 {
#   background-color: #ff7f0e;
# }
# #T_55b22_row3_col1 {
#   background-color: #ffbb78;
# }
# #T_55b22_row4_col1 {
#   background-color: #2ca02c;
# }
# #T_55b22_row5_col1 {
#   background-color: #98df8a;
# }
# #T_55b22_row6_col1 {
#   background-color: #d62728;
# }
# #T_55b22_row7_col1 {
#   background-color: #ff9896;
# }
# #T_55b22_row8_col1 {
#   background-color: #9467bd;
# }
# #T_55b22_row9_col1 {
#   background-color: #c5b0d5;
# }
# </style>
# <table id="T_55b22">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_55b22_level0_col0" class="col_heading level0 col0" >runner</th>
#       <th id="T_55b22_level0_col1" class="col_heading level0 col1" >color</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55b22_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_55b22_row0_col0" class="data row0 col0" >Fiona Hosey</td>
#       <td id="T_55b22_row0_col1" class="data row0 col1" >#1f77b4</td>
#     </tr>
#     <tr>
#       <th id="T_55b22_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_55b22_row1_col0" class="data row1 col0" >Zamora Vielot</td>
#       <td id="T_55b22_row1_col1" class="data row1 col1" >#aec7e8</td>
#     </tr>
#     <tr>
#       <th id="T_55b22_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_55b22_row2_col0" class="data row2 col0" >Aubrey Rutledge</td>
#       <td id="T_55b22_row2_col1" class="data row2 col1" >#ff7f0e</td>
#     </tr>
#     <tr>
#       <th id="T_55b22_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_55b22_row3_col0" class="data row3 col0" >Diana Borohov</td>
#       <td id="T_55b22_row3_col1" class="data row3 col1" >#ffbb78</td>
#     </tr>
#     <tr>
#       <th id="T_55b22_level0_row4" class="row_heading level0 row4" >12</th>
#       <td id="T_55b22_row4_col0" class="data row4 col0" >Abilena Sholomova</td>
#       <td id="T_55b22_row4_col1" class="data row4 col1" >#2ca02c</td>
#     </tr>
#     <tr>
#       <th id="T_55b22_level0_row5" class="row_heading level0 row5" >15</th>
#       <td id="T_55b22_row5_col0" class="data row5 col0" >Jasveer Mehta</td>
#       <td id="T_55b22_row5_col1" class="data row5 col1" >#98df8a</td>
#     </tr>
#     <tr>
#       <th id="T_55b22_level0_row6" class="row_heading level0 row6" >18</th>
#       <td id="T_55b22_row6_col0" class="data row6 col0" >Ava Anello</td>
#       <td id="T_55b22_row6_col1" class="data row6 col1" >#d62728</td>
#     </tr>
#     <tr>
#       <th id="T_55b22_level0_row7" class="row_heading level0 row7" >21</th>
#       <td id="T_55b22_row7_col0" class="data row7 col0" >Zoe Liolis</td>
#       <td id="T_55b22_row7_col1" class="data row7 col1" >#ff9896</td>
#     </tr>
#     <tr>
#       <th id="T_55b22_level0_row8" class="row_heading level0 row8" >24</th>
#       <td id="T_55b22_row8_col0" class="data row8 col0" >Arlinda Veljovic</td>
#       <td id="T_55b22_row8_col1" class="data row8 col1" >#9467bd</td>
#     </tr>
#     <tr>
#       <th id="T_55b22_level0_row9" class="row_heading level0 row9" >27</th>
#       <td id="T_55b22_row9_col0" class="data row9 col0" >Daniela Carlin</td>
#       <td id="T_55b22_row9_col1" class="data row9 col1" >#c5b0d5</td>
#     </tr>
#   </tbody>
# </table>
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2cb9b75d6fa3ba2385055f59594aece {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2cb9b75d6fa3ba2385055f59594aece&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2cb9b75d6fa3ba2385055f59594aece = L.map(
#                 &quot;map_e2cb9b75d6fa3ba2385055f59594aece&quot;,
#                 {
#                     center: [40.719886243968446, -73.65201239756493],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e2cb9b75d6fa3ba2385055f59594aece);
#
#
#
#
#
#             var tile_layer_7175c19f84987b374603ad8cc6c11172 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7175c19f84987b374603ad8cc6c11172.addTo(map_e2cb9b75d6fa3ba2385055f59594aece);
#
#
#             map_e2cb9b75d6fa3ba2385055f59594aece.fitBounds(
#                 [[40.71710518289702, -73.65506504272668], [40.72266730503987, -73.6489597524032]],
#                 {}
#             );
#
#
#         function geo_json_1d7f3303f6da700ecb90e5e2002de45f_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;:
#                     return {&quot;fillColor&quot;: &quot;violet&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 0, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 0, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1d7f3303f6da700ecb90e5e2002de45f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1d7f3303f6da700ecb90e5e2002de45f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot

# %% [markdown]
# Make it great
# -------------
# Here are some more things you can do to customize your map.
#
# ### HTML in popups
#
# You can add HTML markup to your pops to add styles.
# For example, add a `<br>` tag at the end of a line for a new line.
# Or, you can use the `<b>` `</b>` tags for bold text (or `<i>` `</i>`).
# If you want to add a link to another web page, use the anchor tag, `<a href="#link here"> </a>`
# You can even add images in the popup with the `<img>` tag.
#
# You can go back up to our "The campus buildings" section
# and change the data in the `descriptions` dictionary to
# play around with the HTML in the popups.
#
#
# ### Add custom points
# Do you want to add your own "point of interest on the map?
# Here's the idea...
#
# 1. [open Google Maps to the Adelphi campus](https://maps.app.goo.gl/2YntDZjFQp2uhWq58).
# 2. Zoom and pam the map to find the point you want to plot on your own mam.
# 3. Right-click: in the pop up, you will see latitude and longitude points (e.g. 40.72032625951953, -73.65245042948818);
#    Click the points to copy it to your clipboard.
# 4. Use those points to add a `Marker` to your map using the code below.

# %%
from shapely.geometry import Point
# recreate our campus map, call it m
m = campus.explore(color="color", tooltip="title", tooltip_kwds={"labels": False}, style_kwds={ "fillOpacity": 1, "opacity": 0}, popup_kwds={"labels": False}, popup="description")

# dr. uttamchandani's office
point = [40.71913843902625, -73.6519409727994]

folium.CircleMarker(
    location=point,
    radius=5,  # Radius of the circle
    color='blue',  # Border color of the circle
    fill=True,  # Whether to fill the circle
    fill_color='blue',  # Fill color
    fill_opacity=1,  # Fill opacity
    popup="Dr. Uttamchanbani's Office, Rm 227" 
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7a09906395dce3eff8090c2c693b6e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7a09906395dce3eff8090c2c693b6e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7a09906395dce3eff8090c2c693b6e7 = L.map(
#                 &quot;map_e7a09906395dce3eff8090c2c693b6e7&quot;,
#                 {
#                     center: [40.719886243968446, -73.65201239756493],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e7a09906395dce3eff8090c2c693b6e7);
#
#
#
#
#
#             var tile_layer_f4a1c631fe128370a4cb553b391666a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f4a1c631fe128370a4cb553b391666a5.addTo(map_e7a09906395dce3eff8090c2c693b6e7);
#
#
#             map_e7a09906395dce3eff8090c2c693b6e7.fitBounds(
#                 [[40.71710518289702, -73.65506504272668], [40.72266730503987, -73.6489597524032]],
#                 {}
#             );
#
#
#         function geo_json_1232845dd8b2ac8568b2733d898010b7_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;3&quot;: case &quot;4&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;8&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;12&quot;: case &quot;13&quot;: case &quot;14&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;20&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;26&quot;: case &quot;27&quot;:
#                     return {&quot;fillColor&quot;: &quot;violet&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 0, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;fillColor&quot;: &quot;crimson&quot;, &quot;fillOpacity&quot;: 1, &quot;opacity&quot;: 0, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_1232845dd8b2ac8568b2733d898010b7_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_1232845dd8b2ac8568b2733d898010b7_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_1232845dd8b2ac8568b2733d898010b7_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_1232845dd8b2ac8568b2733d898010b7_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_1232845dd8b2ac8568b2733d898010b7.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_1232845dd8b2ac8568b2733d898010b7_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
