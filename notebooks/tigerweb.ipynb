# %%
import geopandas as gpd
import requests

# %%
url = "https://tigerweb.geo.census.gov/arcgis/rest/services/Generalized_ACS2022/State_County/MapServer/8/query?where=1%3D1&text=&objectIds=&time=&timeRelation=esriTimeRelationOverlaps&geometry=&geometryType=esriGeometryEnvelope&inSR=&spatialRel=esriSpatialRelIntersects&distance=&units=esriSRUnit_Foot&relationParam=&outFields=&returnGeometry=true&returnTrueCurves=false&maxAllowableOffset=&geometryPrecision=&outSR=&havingClause=&returnIdsOnly=false&returnCountOnly=false&orderByFields=&groupByFieldsForStatistics=&outStatistics=&returnZ=false&returnM=false&gdbVersion=&historicMoment=&returnDistinctValues=false&resultOffset=&resultRecordCount=&returnExtentOnly=false&sqlFormat=none&datumTransformation=&parameterValues=&rangeValues=&quantizationParameters=&featureEncoding=esriDefault&f=geojson"
gdf = gpd.read_file(url)
gdf
# resp = requests.get(url)
# resp.text
# Out:
#                                         BASENAME  \
# 0                                   Rhode Island
# 1                                       Arkansas
# 2                                       New York
# 3                                           Iowa
# 4                                           Utah
# 5                                       Virginia
# 6                                        Wyoming
# 7                                  West Virginia
# 8                                        Indiana
# 9                                         Kansas
# 10                                         Idaho
# 11                                        Nevada
# 12                                    New Mexico
# 13                                   Puerto Rico
# 14                                         Texas
# 15                                      Kentucky
# 16                                          Ohio
# 17                                       Georgia
# 18                                        Oregon
# 19                                  Pennsylvania
# 20                                      Missouri
# 21                                North Carolina
# 22  Commonwealth of the Northern Mariana Islands
# 23                                American Samoa
# 24                                       Montana
# 25                                       Arizona
# 26                                      Nebraska
# 27                                    Washington
# 28                                  South Dakota
# 29                                    California
# 30                                       Alabama
# 31                                     Wisconsin
# 32                                   Mississippi
# 33                                      Colorado
# 34                                      Oklahoma
# 35                                     Tennessee
# 36                                     Louisiana
# 37                                      Michigan
# 38                                 Massachusetts
# 39                                       Florida
# 40                                        Alaska
# 41                                      Maryland
# 42                                South Carolina
# 43                                      Illinois
# 44                                       Vermont
# 45                                    New Jersey
# 46                                     Minnesota
# 47                                  North Dakota
# 48                                         Maine
# 49                                 New Hampshire
# 50                                   Connecticut
# 51                  United States Virgin Islands
# 52                                        Hawaii
# 53                                      Delaware
# 54                          District of Columbia
# 55                                          Guam
#
#                                              geometry
# 0   MULTIPOLYGON (((-71.86211 41.31661, -71.86277 ...
# 1   POLYGON ((-94.61792 36.49941, -94.61531 36.484...
# 2   MULTIPOLYGON (((-79.76215 42.24305, -79.76214 ...
# 3   POLYGON ((-96.6397 42.73707, -96.63862 42.7349...
# 4   POLYGON ((-114.05296 37.59278, -114.05274 37.5...
# 5   MULTIPOLYGON (((-83.67461 36.60308, -83.67541 ...
# 6   POLYGON ((-111.05689 44.86666, -111.05642 44.7...
# 7   POLYGON ((-82.643 38.16956, -82.64474 38.16549...
# 8   POLYGON ((-88.09566 37.90581, -88.09789 37.901...
# 9   POLYGON ((-102.05174 40.00308, -102.05157 39.8...
# 10  POLYGON ((-117.24267 44.39655, -117.24303 44.3...
# 11  POLYGON ((-120.00574 39.22866, -120.00575 39.2...
# 12  POLYGON ((-109.05017 31.48, -109.05004 31.3325...
# 13  MULTIPOLYGON (((-67.26826 18.36699, -67.27135 ...
# 14  POLYGON ((-106.64548 31.89867, -106.6453 31.89...
# 15  MULTIPOLYGON (((-89.40565 36.52816, -89.41729 ...
# 16  MULTIPOLYGON (((-84.82016 39.22723, -84.82012 ...
# 17  POLYGON ((-85.60517 34.98468, -85.59939 34.951...
# 18  POLYGON ((-124.55244 42.84057, -124.54418 42.8...
# 19  POLYGON ((-80.51989 40.90666, -80.51979 40.900...
# 20  POLYGON ((-95.77355 40.57821, -95.7747 40.5735...
# 21  MULTIPOLYGON (((-84.31748 35.02196, -84.32187 ...
# 22  MULTIPOLYGON (((145.68945 15.12778, 145.6912 1...
# 23  MULTIPOLYGON (((-170.847 -14.32008, -170.84685...
# 24  POLYGON ((-116.04905 48.48102, -116.04989 48.4...
# 25  POLYGON ((-114.79968 32.59362, -114.81418 32.5...
# 26  POLYGON ((-104.05321 41.19995, -104.05351 41.1...
# 27  MULTIPOLYGON (((-124.73175 48.17, -124.73317 4...
# 28  POLYGON ((-104.0577 44.99743, -104.05591 44.87...
# 29  MULTIPOLYGON (((-124.4086 40.4432, -124.40959 ...
# 30  MULTIPOLYGON (((-88.47323 31.89386, -88.47264 ...
# 31  MULTIPOLYGON (((-92.88811 45.62838, -92.88804 ...
# 32  MULTIPOLYGON (((-91.65501 31.25181, -91.65491 ...
# 33  POLYGON ((-109.06025 38.59933, -109.05996 38.5...
# 34  POLYGON ((-103.00256 36.52659, -103.00243 36.5...
# 35  POLYGON ((-90.30971 35.00848, -90.3093 34.9956...
# 36  MULTIPOLYGON (((-94.04315 32.69303, -94.04315 ...
# 37  MULTIPOLYGON (((-86.82483 41.76024, -86.82363 ...
# 38  MULTIPOLYGON (((-73.50814 42.08626, -73.50304 ...
# 39  MULTIPOLYGON (((-87.63484 30.86611, -87.63494 ...
# 40  MULTIPOLYGON (((-168.12893 65.65574, -168.1346...
# 41  MULTIPOLYGON (((-79.48681 39.29637, -79.48765 ...
# 42  POLYGON ((-83.35324 34.72865, -83.35249 34.716...
# 43  POLYGON ((-91.51297 40.18106, -91.51308 40.178...
# 44  POLYGON ((-73.43774 44.04501, -73.43688 44.042...
# 45  POLYGON ((-75.5591 39.62906, -75.55961 39.6242...
# 46  POLYGON ((-97.23921 48.96868, -97.23888 48.966...
# 47  POLYGON ((-104.04865 48.86573, -104.0489 48.84...
# 48  MULTIPOLYGON (((-71.07841 45.30623, -71.08392 ...
# 49  POLYGON ((-72.55627 42.85529, -72.55725 42.853...
# 50  POLYGON ((-73.72777 41.1007, -73.72258 41.0936...
# 51  MULTIPOLYGON (((-64.88745 17.76336, -64.89518 ...
# 52  MULTIPOLYGON (((-156.05722 19.74254, -156.0643...
# 53  MULTIPOLYGON (((-75.78886 39.67848, -75.7889 3...
# 54  POLYGON ((-77.11976 38.93434, -77.1179 38.9324...
# 55  POLYGON ((144.62253 13.45301, 144.61974 13.442...
