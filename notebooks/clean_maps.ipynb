# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from matplotlib.colors import to_hex

import os
files = os.listdir('.')

# use os.walk() to iterate files and dirs in pwd
t = []
for root, dir, files in os.walk("."):
    t.extend([os.path.join(root, f) for f in files if f.endswith("kml") ])

t

runs = []
for i, f in enumerate(t):
    runner = f.split("_")[0][2:]
    df = gpd.read_file(f)
    df["type"] = "route"
    df.iloc[1, df.columns.get_loc('type')] = 'start'
    df.iloc[2, df.columns.get_loc('type')] = 'end'
    df["runner"] = runner 
    df["index"] = i
    runs.append(df)

data = pd.concat(runs)
data["color"] = "orange"

data
# Out:
#                                                 Name Description  \
# 0                                         0.79mi Run
# 1                                         0.79mi Run
# 2                                         0.79mi Run
# 0                                  September 10,2024
# 1                                  September 10,2024
# 2                                  September 10,2024
# 0                             Today’s Activity (Map)
# 1                             Today’s Activity (Map)
# 2                             Today’s Activity (Map)
# 0                                    Tuesday 9/10/24
# 1                                    Tuesday 9/10/24
# 2                                    Tuesday 9/10/24
# 0                                   Abilenas tuesday
# 1                                   Abilenas tuesday
# 2                                   Abilenas tuesday
# 0                                         2.64mi Run
# 1                                         2.64mi Run
# 2                                         2.64mi Run
# 0                                    Tuesday workout
# 1                                    Tuesday workout
# 2                                    Tuesday workout
# 0                                         Campus run
# 1                                         Campus run
# 2                                         Campus run
# 0  Walk from my car to Class then back to my Car ...
# 1  Walk from my car to Class then back to my Car ...
# 2  Walk from my car to Class then back to my Car ...
# 0                                  Day around Campus
# 1                                  Day around Campus
# 2                                  Day around Campus
#
#                                             geometry   type  \
# 0  LINESTRING Z (-73.65101 40.72159 0, -73.65101 ...  route
# 1                     POINT Z (-73.65101 40.72159 0)  start
# 2                     POINT Z (-73.65533 40.72273 0)    end
# 0  LINESTRING Z (-73.65316 40.72217 0, -73.65316 ...  route
# 1                     POINT Z (-73.65316 40.72217 0)  start
# 2                      POINT Z (-73.6513 40.71199 0)    end
# 0  LINESTRING Z (-73.65222 40.71986 0, -73.6522 4...  route
# 1                     POINT Z (-73.65222 40.71986 0)  start
# 2                      POINT Z (-73.6522 40.71977 0)    end
# 0  LINESTRING Z (-73.65272 40.72175 0, -73.65262 ...  route
# 1                     POINT Z (-73.65272 40.72175 0)  start
# 2                      POINT Z (-73.65362 40.7226 0)    end
# 0  LINESTRING Z (-73.65075 40.72274 0, -73.65077 ...  route
# 1                     POINT Z (-73.65075 40.72274 0)  start
# 2                     POINT Z (-73.65247 40.72232 0)    end
# 0  LINESTRING Z (-73.65301 40.72158 0, -73.65301 ...  route
# 1                     POINT Z (-73.65301 40.72158 0)  start
# 2                     POINT Z (-73.66072 40.72361 0)    end
# 0  LINESTRING Z (-73.65151 40.71862 0, -73.65149 ...  route
# 1                     POINT Z (-73.65151 40.71862 0)  start
# 2                     POINT Z (-73.65175 40.71853 0)    end
# 0  LINESTRING Z (-73.65107 40.72192 0, -73.65107 ...  route
# 1                     POINT Z (-73.65107 40.72192 0)  start
# 2                     POINT Z (-73.65086 40.72229 0)    end
# 0  LINESTRING Z (-73.65102 40.71956 0, -73.65103 ...  route
# 1                     POINT Z (-73.65102 40.71956 0)  start
# 2                     POINT Z (-73.65102 40.71958 0)    end
# 0  LINESTRING Z (-73.65174 40.71899 0, -73.65176 ...  route
# 1                     POINT Z (-73.65174 40.71899 0)  start
# 2                     POINT Z (-73.65183 40.71902 0)    end
#
#               runner  index   color
# 0        Fiona Hosey      0  orange
# 1        Fiona Hosey      0  orange
# 2        Fiona Hosey      0  orange
# 0      Zamora Vielot      1  orange
# 1      Zamora Vielot      1  orange
# 2      Zamora Vielot      1  orange
# 0    Aubrey Rutledge      2  orange
# 1    Aubrey Rutledge      2  orange
# 2    Aubrey Rutledge      2  orange
# 0      Diana Borohov      3  orange
# 1      Diana Borohov      3  orange
# 2      Diana Borohov      3  orange
# 0  Abilena Sholomova      4  orange
# 1  Abilena Sholomova      4  orange
# 2  Abilena Sholomova      4  orange
# 0      Jasveer Mehta      5  orange
# 1      Jasveer Mehta      5  orange
# 2      Jasveer Mehta      5  orange
# 0         Ava Anello      6  orange
# 1         Ava Anello      6  orange
# 2         Ava Anello      6  orange
# 0         Zoe Liolis      7  orange
# 1         Zoe Liolis      7  orange
# 2         Zoe Liolis      7  orange
# 0   Arlinda Veljovic      8  orange
# 1   Arlinda Veljovic      8  orange
# 2   Arlinda Veljovic      8  orange
# 0     Daniela Carlin      9  orange
# 1     Daniela Carlin      9  orange
# 2     Daniela Carlin      9  orange

# %%
cmap = plt.get_cmap('tab20')
data["color"] = data["index"].apply(lambda x: to_hex(cmap(x)))
# data.explore(color=data["color"], tooltip="runner", legend=True)

data = data[['index',  'runner',  'color', 'type', 'geometry']]
data.to_file("runs.geojson", driver='GeoJSON')
